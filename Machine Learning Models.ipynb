# %%
import numpy as np
import pandas as pd
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# Out:
# C:\Users\Tarik\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Read CSV file
data = pd.read_csv('preprocessed.csv')
data = data[['Posts', 'Label']]

# %%
data
# Out:
#                                                   Posts      Label
# 0     እነዚህን ወሳኝ ጉዳዮችን የሚያስፈፅም አካል እንዲቋቋምና ክትትል እንዲደረ...       Free
# 1     ጃዋር አልበግዳዲ በግርግር ስልጣን ለመያዝ የሚያደርገው ነገር ብዙ ስራ ፈ...  Offensive
# 2      ምን ሆናችሁ ኦርቶዶክሶች ሰሞኑን ፖለቲካ ገባ እንዴ ውስጣችኋይዟችሁ ወደ...       Free
# 3     ስለ አሳምነው የምትፅፈው ነገር አሳምነው ለአማራ የነበረው ተቆርቋሪነት አ...       Free
# 4     አጋጣሚውን ተጠቅመው የእስክንድር ነጋን ስም እና ትግል ለማዳከም የሚፈልጉ...  Offensive
# ...                                                 ...        ...
# 5725      ኦህዴድ እራሱ ባመጣዉ ቀዉስ ተናዉጦ መዉጫ ቀዳዳ     እየፈለገ ነዉ    Offensive
# 5726                                 ኦሮሞ ሀገር መምራት አይችልም  Offensive
# 5727  ሲማረኩ በሚሰጡት  አትታለሉ  ማርኮ ከማብላት መረሸን ይቀላል  ትግሬ ጎረ...  Offensive
# 5728   በኦሮሞ  የተሞሉ ሴገጤዎች የወሎ ኦሮሞን ምንም ስሌ  የማያውቅን ህዝብ ...  Offensive
# 5729  ኮሮና ቫይረስ ኢትዮጵያ ገባ እያሉ  ሲንጫጩ ስታይ አረ ፈታ በሉ ከቫይረሱ...  Offensive
#
# [5730 rows x 2 columns]

# %%
# Preprocessing and training data
sentences = data['Posts'].tolist()
labels = data['Label'].tolist()

# %%
# Tokenization and preprocessing
tokenized_sentences = [sentence.split() for sentence in sentences]

# %%
tokenized_sentences
# Out:
# [['እነዚህን',
#   'ወሳኝ',
#   'ጉዳዮችን',
#   'የሚያስፈፅም',
#   'አካል',
#   'እንዲቋቋምና',
#   'ክትትል',
#   'እንዲደረግ',
#   'በመግለጫው',
#   'ጠይቀዋል'],
#  ['ጃዋር',
#   'አልበግዳዲ',
#   'በግርግር',
#   'ስልጣን',
#   'ለመያዝ',
#   'የሚያደርገው',
#   'ነገር',
#   'ብዙ',
#   'ስራ',
#   'ፈት',
#   'ቄሮ',
#   'ሊያስጨርስ',
#   'እንጂ',
#   'የስልጣን',
#   'ሽታዋን',
#   'አያገኝም',
#   'ያባቱ',
#   'ሀገር',
#   'የመን',
#   'ይሂድ',
#   'ስልጣን',
#   'ካማረው',
#   'ወይ',
#   'ደግሞ',
#   'በናቱ',
#   'አማራ',
#   'ስለሆለ',
#   'አማራ',
#   'ክልል',
#   'ሂዶ',
#   'ይወዳደር'],
#  ['ምን',
#   'ሆናችሁ',
#   'ኦርቶዶክሶች',
#   'ሰሞኑን',
#   'ፖለቲካ',
#   'ገባ',
#   'እንዴ',
#   'ውስጣችኋይዟችሁ',
#   'ወደዱም',
#   'ጠሉም',
#   'ኢዮጵያ',
#   'አትፈርስም',
#   'ኦርቶዶክስ',
#   'አትከፈልም',
#   'ይህንን',
#   'ያለው',
#   'ጠቅላይ',
#   'ሚንስትር',
#   'አቢይ',
#   'አህመድ',
#   'ነውበናትህ',
#   'ጡጦ',
#   'ግዛልን'],
#  ['ስለ',
#   'አሳምነው',
#   'የምትፅፈው',
#   'ነገር',
#   'አሳምነው',
#   'ለአማራ',
#   'የነበረው',
#   'ተቆርቋሪነት',
#   'አሪፍ',
#   'ነበር',
#   'ነገር',
#   'ግን',
#   'እነደ',
#   'ፀጥታ',
#   'ዘርፍ',
#   'ሀላፊ',
#   'ሆኖ',
#   'ሲሰራ',
#   'የፌደራል',
#   'ፓሊስም',
#   'ሆነ',
#   'የኦነግ',
#   'ሰራዊት',
#   'ወደ',
#   'አማራ',
#   'ክልል',
#   'ከሰኞ',
#   'አርብ',
#   'አየገቡ',
#   'መረጃው',
#   'ደርሶት',
#   'ነበር',
#   'ለምን',
#   'ዝግጅት',
#   'አላደረገም',
#   'የሆነ',
#   'ነገር',
#   'ሊፈፀም',
#   'እንደሆነ',
#   'ካወቀ',
#   'እንዴት',
#   'ዝም',
#   'ብሎ',
#   'ይቀመጣል'],
#  ['አጋጣሚውን',
#   'ተጠቅመው',
#   'የእስክንድር',
#   'ነጋን',
#   'ስም',
#   'እና',
#   'ትግል',
#   'ለማዳከም',
#   'የሚፈልጉት',
#   'ድንኳኑ',
#   'ጢም',
#   'ሲል',
#   'አሳላፊ',
#   'መሆን',
#   'የሚዳዳቸው',
#   'ሆድ',
#   'አደሮች',
#   'ናቸው',
#   'እስክንድር',
#   'የተዋህዶ',
#   'ስብሰባ',
#   'እኔም',
#   'ይመለከተኛል',
#   'እንጂ',
#   'እኔ',
#   'ነኝ',
#   'መሪው',
#   'እና',
#   'አስተባባሪው',
#   'አላለም',
#   'በእለቱ',
#   'ግን',
#   'መግለጫ',
#   'የመስጠት',
#   'መብት',
#   'እንዳለው',
#   'መዘንጋት',
#   'የለበትም',
#   'ስብሰባውን',
#   'ተያይዞም',
#   'መግለጫ',
#   'ቢሰጥ',
#   'ክፋቱ',
#   'ምንድን',
#   'ነው',
#   'መግለጫው',
#   'ምን',
#   'እንደሆነ',
#   'ሳንሰማ',
#   'እስክንድርን',
#   'ለመወረፍ',
#   'እና',
#   'ለማንቋሸሽ',
#   'ማሰብ',
#   'እጅግ',
#   'ነውር',
#   'ብቻ',
#   'ሳይሆን',
#   'አላዋቂነትም',
#   'ነው',
#   'እስክንድር',
#   'የ',
#   'አዲስ',
#   'አበባ',
#   'ጉዳይን',
#   'ከፊት',
#   'ሆኖ',
#   'በመምራት',
#   'እነ',
#   'ጃዋርን',
#   'እና',
#   'ተለጣፊውን',
#   'ግንቦት',
#   'ሰባት',
#   'ከፍ',
#   'ሲልም',
#   'የ',
#   'አብይን',
#   'ሁነኛ',
#   'ባህሪይ',
#   'ያጋለጠ',
#   'ሰው',
#   'ነው',
#   'ሲደገስ',
#   'እኛ',
#   'ነን',
#   'ማለት',
#   'የፖለቲካ',
#   'ባህላችን',
#   'ስለሆነ',
#   'እንጂ',
#   'እስክንድር',
#   'የከፈለውን',
#   'መስእዋትነት',
#   'ላለመክፈል',
#   'ወደ',
#   'ውጭ',
#   'ሸሽተው',
#   'የወጡት',
#   'ይህንን',
#   'የእስክንድርን',
#   'መግለጫ',
#   'ለማሳጫነት',
#   'መጠቀማቸው',
#   'ሊያሳፍራቸው',
#   'ይገባል',
#   'ኦነጎች',
#   'ህወሀቶች',
#   'እና',
#   'ግንቦት',
#   'ሰባቶች',
#   'በጥምረት',
#   'እስክንድር',
#   'ላይ',
#   'የተነሱት',
#   'ሶስቱም',
#   'አካላቶች',
#   'በ',
#   'አዲስ',
#   'አበባ',
#   'ላይ',
#   'ለ',
#   'አዲስ',
#   'አበባ',
#   'ህዝብ',
#   'የማይጠቅም',
#   'የስልጣን',
#   'ጥም',
#   'የወለደው',
#   'ህልም',
#   'ስላላቸው',
#   'ነው',
#   'እነ',
#   'ግርማ',
#   'ሰይፉ',
#   'እና',
#   'መሰል',
#   'የታሪክ',
#   'ውሾች',
#   'ከእስክንድር',
#   'በላይ',
#   'ለ',
#   'እምነታቸው',
#   'የተቆረቆሩ',
#   'በማስመሰል',
#   'ደጋግመው',
#   'ለካዱት',
#   'ህዝብ',
#   'እንደ',
#   'ጠበቃም',
#   'ሲያደርጋቸው',
#   'ማየት',
#   'ከማሳቀቅ',
#   'ከፍ',
#   'ብሎ',
#   'ያስቃል',
#   'እየተስተዋለ',
#   'ልካችንን',
#   'እንወቅ'],
#  ['ትክክል', 'ዝምብለው', 'ያጫፍራሉ'],
#  ['የእስር',
#   'ፍቅሩ',
#   'እልልል',
#   'ያስብለዋል',
#   'እንጂ',
#   'አብይ',
#   'ይሄን',
#   'ሰውዬ',
#   'ቢለምነው',
#   'አያስረውም',
#   'እስር',
#   'ያገነነው',
#   'ጅል'],
#  ['መግለጫ',
#   'የመስጠት',
#   'መብት',
#   'ቢኖረውም',
#   'አሁን',
#   'ባለው',
#   'ሁኔታ',
#   'ማድረግ',
#   'ፈፅሞ',
#   'ስህተት',
#   'ነው',
#   'የቤተክርስቲያኗን',
#   'አጀንዳ',
#   'ለፖለቲካ',
#   'ጥቅም',
#   'ሀይጃክ',
#   'ማድረግ',
#   'ማለት',
#   'ነው'],
#  ['ትክክል',
#   'ሄኔኬ',
#   'ግን',
#   'እስክንድር',
#   'እራሱን',
#   'መጠበቅ',
#   'አለበት',
#   'ይህንን',
#   'ግርግር',
#   'ተገን',
#   'በማድረግ',
#   'ብዙ',
#   'ስው',
#   'በላወቺ',
#   'እንዳሉ',
#   'መገንዘብ',
#   'አለብን',
#   'እስክንድርም',
#   'ተከታዪቹም',
#   'ፈጣሪ',
#   'ይጠብቃቸው'],
#  ['ሰኔ',
#   'የተደርገውን',
#   'መገመት',
#   'ይቻላል',
#   'አሁንም',
#   'ሌላ',
#   'ችግር',
#   'አንፈልግም',
#   'ከፈለገ',
#   'መልእክቱን',
#   'በአስራት',
#   'ያስተላልፍ',
#   'ለኦርቶዶክስ',
#   'ድጋፍ',
#   'ከፈለገ',
#   'አሁን',
#   'የሱ',
#   'መግለጫ',
#   'ሳይሆን',
#   'የተያዘውን',
#   'ሰልፍ',
#   'ስለ',
#   'ቤተክርስቲያን',
#   'ነው',
#   'ምክንያት',
#   'ነው',
#   'የሚፈልጉት',
#   'ሰውን',
#   'ለማሰናከል',
#   'የማንርሳቸውን',
#   'አተናል',
#   'ባህር',
#   'ዳር',
#   'ከመሄድ',
#   'በፊት',
#   'ብዙ',
#   'ልጆች',
#   'ችግር',
#   'ይፈጠራል',
#   'እያሉ',
#   'ነበር',
#   'ይህ',
#   'ነገር',
#   'ችግር',
#   'ይፈጥራል',
#   'እናስተውል'],
#  ['አሰለቻችሁን', 'መግለጫ', 'መግለጫ', 'መግለጫ', 'የምን', 'መግለጫ', 'ጋጋታ', 'ነው'],
#  ['ዝም',
#   'ብሌ',
#   'ወሬ',
#   'ማብዛት',
#   'ምንስ',
#   'ጥቅም',
#   'አለው',
#   'ሁሉም',
#   'ወደ',
#   'ተግባርና',
#   'አንድነት',
#   'መምጣቱ',
#   'ብቻ',
#   'ነው',
#   'አዋጭውና',
#   'ጠቃሚው'],
#  ['እስክንድር',
#   'የሚናገረውን',
#   'ለመረዳት',
#   'ወይም',
#   'የሚያደርገውን',
#   'ነገር',
#   'በደንብ',
#   'ለማወቅ',
#   'ዳግም',
#   'መፈጠር',
#   'ያስፈልጋል',
#   'ሰዎች',
#   'በደንብ',
#   'ስለማይረዱት',
#   'አንድ',
#   'ነገር',
#   'ባደረገ',
#   'እና',
#   'በተናገረ',
#   'ቁጥር',
#   'በአንድ',
#   'አቅጣጫ',
#   'ብቻ',
#   'ያዩታል',
#   'ወይም',
#   'ሀሳቡን',
#   'አይረዱትም',
#   'ላይ',
#   'ላዩን',
#   'ብቻ',
#   'በማየት',
#   'ይፈርዳሉ'],
#  ['እስክንድር',
#   'በማንኛውም',
#   'ትግል',
#   'መገኘት',
#   'ያለበት',
#   'እና',
#   'መግለጫም',
#   'መስጠት',
#   'ያለበት',
#   'ምርጥ',
#   'ዜጋ',
#   'ነው'],
#  ['ቆማጣ', 'ሁላ'],
#  ['በሌላ', 'ጊዜ', 'ቢያደርገው', 'መልካም', 'ነው'],
#  ['ለሌሎች', 'መጠቀሚያ', 'እንዳይሆን', 'መጠንቀቅ', 'አለበት'],
#  ['ሲጀመር',
#   'ሰልፉ',
#   'ሀይማኖታዊ',
#   'እንጂ',
#   'ፖለቲካዊ',
#   'አይደለም',
#   'ስለሆነም',
#   'የየትኛውም',
#   'ፖለቲካ',
#   'ደጋፊና',
#   'አባል',
#   'ይሳተፍበታል',
#   'ተብሎ',
#   'ይጠበቃል',
#   'እስክንድር',
#   'ደግሞ',
#   'ፖለቲከኛ',
#   'እንጂ',
#   'ሀይማኖተኛ',
#   'አይደለም',
#   'በዚህ',
#   'አጋጣሚ',
#   'ፖለቲከኛ',
#   'አይደለም',
#   'ጋዜጠኛ',
#   'ነው',
#   'ብለህ',
#   'እንደማትሞግተኝ',
#   'ባለ',
#   'ሙሉ',
#   'ተስፋ',
#   'ነኝ',
#   'እናም',
#   'የሁሉም',
#   'በሆነች',
#   'ሀይማኖት',
#   'ላይ',
#   'የአንድ',
#   'ወገን',
#   'ፖለቲካ',
#   'አራማጅ',
#   'ግለሰብ',
#   'ምንም',
#   'አይነት',
#   'መግለጫ',
#   'የመስጠት',
#   'መብት',
#   'የለውም',
#   'ቢሰጥም',
#   'ህብረቱን',
#   'ያፈርሰዋል',
#   'እንጂ',
#   'ምንም',
#   'አይጠቅመውም'],
#  ['ሄኖክየሺጥላ',
#   'በዚህ',
#   'ፅሁፍህ',
#   'ከስንቱ',
#   'ጋር',
#   'ነው',
#   'አማራና',
#   'ኦርቶዶክስን',
#   'የምታጋጨው',
#   'ስትፅፍ',
#   'ሀቀኛ',
#   'አቃም',
#   'ያለህ',
#   'መሆን',
#   'ይገባሀል',
#   'ደግሞ',
#   'ምን',
#   'አገባህ',
#   'ስለ',
#   'እስክንድር',
#   'ማቅራራት',
#   'ዋጋ',
#   'የለውም',
#   'እንደ',
#   'እስክንድር',
#   'ለኢትዮጵያ',
#   'ህዝብ',
#   'እታገላለው',
#   'ካል',
#   'ኢትዮጵያ',
#   'ግባና',
#   'ተገል',
#   'አልዝያ',
#   'ዝም',
#   'ብለህ',
#   'ገንፎህን',
#   'ቀቅል',
#   'እስክንድርን',
#   'ከስንቱ',
#   'ጋር',
#   'ይጋጭ',
#   'እረ',
#   'ስከን',
#   'በል',
#   'እባክህን'],
#  ['ምን',
#   'ሆናችሁ',
#   'ኦርቶዶክሶች',
#   'ሰሞኑን',
#   'ፖለቲካ',
#   'ገባ',
#   'እንዴ',
#   'ውስጣችኋይዟችሁ',
#   'ወደዱም',
#   'ጠሉም',
#   'ኢትዮጵያ',
#   'አትፈርስም',
#   'ኦርቶዶክስ',
#   'አትከፈልም',
#   'ይህንን',
#   'ያለው',
#   'ጠቅላይ',
#   'ሚንስትር',
#   'አቢይ',
#   'አህመድ',
#   'ነው'],
#  ['ስለ',
#   'አሳምነው',
#   'የምትፅፈው',
#   'ነገር',
#   'አሳምነው',
#   'ለአማራ',
#   'የነበረው',
#   'ተቆርቋሪነት',
#   'አሪፍ',
#   'ነበር',
#   'ነገር',
#   'ግን',
#   'እነደ',
#   'ፀጥታ',
#   'ዘርፍ',
#   'ሀላፊ',
#   'ሆኖ',
#   'ሲሰራ',
#   'የፌደራል',
#   'ፓሊስም',
#   'ሆነ',
#   'የኦነግ',
#   'ሰራዊት',
#   'ወደ',
#   'አማራ',
#   'ክልል',
#   'ከሰኞ',
#   'አርብ',
#   'አየገቡ',
#   'መረጃው',
#   'ደርሶት',
#   'ነበር',
#   'ለምን',
#   'ዝግጅት',
#   'አላደረገም',
#   'የሆነ',
#   'ነገር',
#   'ሊፈፀም',
#   'እንደሆነ',
#   'ካወቀ',
#   'እንዴት',
#   'ዝም',
#   'ብሎ',
#   'ይቀመጣል'],
#  ['አርቲስቶች', 'ዘፈኑና', 'እኛም', 'አብረን', 'እንዝፈን', 'እንዴ'],
#  ['ይሄን',
#   'ግም',
#   'የሆነ',
#   'ውሽልሽል',
#   'አንድ',
#   'የሚለው',
#   'ይጥፋ',
#   'ምንም',
#   'እኮ',
#   'የመንግስት',
#   'ሁኔታ',
#   'የለውም',
#   'መንደሬ',
#   'ነገር',
#   'ነው'],
#  ['ጡጦ', 'ብቻ', 'ሳይሆን', 'ያባቱን', 'ቦት', 'ጫማም', 'ጨምሮ', 'ይላከው'],
#  ['ሰማዩ', 'ባዶ', 'ነዉሄኖክ', 'የጅብጥላ', 'አእምሮ', 'ባዶ', 'ነወወ'],
#  ['ይንቀቱ', 'ንቀት', 'አነጋገሩ', 'ይመሰክራል', 'ይሄ', 'ከንቱ', 'መና', 'ይሆነ', 'አይሁድ'],
#  ['አንተ', 'ለጡጦ', 'እንጂ', 'ለምግብ', 'መች', 'ደረስክ', 'ጡጦውንም', 'ነክሰህ', 'ካልበሳኸው', 'ነው'],
#  ['ተዋናይ', 'አብይ'],
#  ['አይ', 'አጭቤው', 'ሁሌ', 'እንዳሾፈን'],
#  ['አብይ', 'የውሸት', 'ስሙ', 'ይመስለኛልዶር', 'ነውየት', 'ተማረ'],
#  ['ጦጦ', 'ለተና', 'ለጫኔ', 'ለህንጭጭ', 'ፖለቲከኞች', 'ይገዛላችጏል', 'ማሙሽዬ'],
#  ['ህዝብ', 'የሚገባውን', 'መሪ', 'ያገኛል', 'ያለው', 'ማን', 'ነበር'],
#  ['እየተያየን', 'ተለያየን', 'ምድረ', 'ቆምጬ', 'ከኦሮሚያ', 'ተነቅሎ', 'ይወጣል'],
#  ['ወናፍ', 'በለው'],
#  ['ማርያምን', 'ያስብላል'],
#  ['ዛሬ',
#   'ነው',
#   'እንዴ',
#   'ጡጦ',
#   'የተገዛልህ',
#   'ቆዬ',
#   'እኮ',
#   'ድሮድሮ',
#   'አእሚትሙቅስትበጠብጥ',
#   'እኮ',
#   'ነው',
#   'የተገዛልህ',
#   'ክክክ'],
#  ['ይቀልዳል', 'ይቀደዳል', 'ይቀላምዳል'],
#  ['ጥያቄውን', 'እናወግዛለን', 'ወይስ', 'ጥያቄው', 'ኢትዮጵያን', 'አያፈርስም', 'ይብራራ'],
#  ['ሳይታለም', 'የተፈታ', 'ነው', 'በልልኝማ'],
#  ['አይ', 'አንተ', 'ጡጦ', 'ገዝቶልንማ', 'ጡጦዉን', 'ዛሬም', 'ድረስ', 'የሚጠቡኮ', 'አሉ'],
#  ['አንተ', 'እራስህ', 'ጡጦ', 'አይደለህ', 'እንዴ', 'ምን', 'ይገዛልሀል'],
#  ['እርግጠኛ',
#   'ባልሆነም',
#   'ፈጣሪ',
#   'ተቀይሞናል',
#   'ምልክቱ',
#   'መሪዋቻችን',
#   'በጣም',
#   'ይንቁናል',
#   'የነሱ',
#   'ያህል',
#   'የሚገባን',
#   'አይመስላቸውም'],
#  ['አስመሳይ', 'ሌባ', 'የህዝቡ', 'ከዳር', 'እስከዳር', 'መነሳት', 'አይቶ', 'አቅጣጫ', 'ማስቀየሩ', 'ነው'],
#  ['ይህ', 'መርዘኛ', 'እባብ', 'የጭቃ', 'እሾህ'],
#  ['አብይ', 'እንደዚህ', 'እያለ', 'ሁሌ', 'ይሸውዳቹሀል', 'ሿሿ'],
#  ['ይሄ', 'ሰውዬ', 'ግን', 'ያልተናገረውን', 'ነገር', 'ጠይቀኝ'],
#  ['እና',
#   'ምን',
#   'አባህ',
#   'ይሸከምህ',
#   'ከዚ',
#   'በላይ',
#   'የመስቀለኛ',
#   'መንገድ',
#   'ልጅ',
#   'ባፋንኩሎ',
#   'አሁን',
#   'ሰው',
#   'ሰልችቴታል',
#   'የናንተ',
#   'አንሱኝ',
#   'ጣሉኝ',
#   'ማለት'],
#  ['ወደው', 'አይስቁ'],
#  ['ኦ', 'የነኬኛ', 'ቦለጢቃ', 'አቅረፈደንአቦ', 'ወዲያ', 'በሉ', 'በሏቸው'],
#  ['አብይ',
#   'በጥራቃው',
#   'ሁሌም',
#   'ምርጥ',
#   'ቃላት',
#   'እየተጠቀመ',
#   'ሿሿ',
#   'መስራት',
#   'ይችላል',
#   'ግን',
#   'አሁን',
#   'ተነቃቅተናል'],
#  ['አንተን',
#   'ድርግም',
#   'አርጎ',
#   'ይዝጋህ',
#   'አየክ',
#   'ጋላ',
#   'ስትወን',
#   'ቀዳዳ',
#   'ብቻ',
#   'ነው',
#   'ማሰብ',
#   'የምትችል'],
#  ['ምቀኛ',
#   'እና',
#   'ለመታወቅ',
#   'የሚፈልግ',
#   'ቀድሞ',
#   'አፉ',
#   'ይቀባጥራል',
#   'ወንድ',
#   'ከሆንክ',
#   'እዚ',
#   'አንዴ',
#   'ና',
#   'ለነገሩ',
#   'አንተ',
#   'ለጓደኞችህም',
#   'ለአማራም',
#   'አትመችም',
#   'በወከንቱ',
#   'እንቁራሪት'],
#  ['አናቱ', 'ይፍረስ'],
#  ['ፈለገውን',
#   'ይበል',
#   'ከዚህ',
#   'በሆላ',
#   'ኦርቶዶክስን',
#   'እግሯን',
#   'የሚረግጣት',
#   'አንገቱ',
#   'ነው',
#   'እሚቆረጥለት'],
#  ['አስመሳይ', 'እኮ', 'ነው'],
#  ['ይህ',
#   'ጥንብ',
#   'ኤርትራዊ',
#   'ህዝቤን',
#   'እያጃጃለ',
#   'ጢባ',
#   'ጢቤ',
#   'እንደ',
#   'ጉድ',
#   'ይጫወትበታልክክክክክክክክ'],
#  ['የምን', 'ጡጦ', 'ላንተ', 'ቆመጥ', 'ነው', 'የሚያስፈልግ', 'የሆንክ', 'ቡሽቲ'],
#  ['ጡጦ', 'የለም', 'ጣትህን', 'ጥባ'],
#  ['ሂድ', 'እናትህን', 'ብዳ'],
#  ['የበታችነትህን',
#   'ለመሸሸ',
#   'ምታደርገውን',
#   'ጥረት',
#   'ሳናደንቅ',
#   'አናልፍም',
#   'ህውሀትም',
#   'ሆነች',
#   'ህዝቦ',
#   'ግን',
#   'ሁሌም',
#   'የበላይ',
#   'ናቸው',
#   'ይሄን',
#   'መቼም',
#   'ልቦናህ',
#   'ያቀዋልለዚህም',
#   'ነው',
#   'በትግራይ',
#   'ታሪክ',
#   'ስትፎክሩ',
#   'የኖራቹት'],
#  ['ዛሚ', 'መሀሪ', 'የትግራይ', 'ታሪክ', 'ምንድን', 'ነው'],
#  ['አለም', 'ፀሀይ', 'ሀይሌ', 'አረቄያም'],
#  ['እግሄር', 'እንኳን', 'አለደረገኝ', 'ባለመሆኔ', 'በጣም', 'እኮራለሁ'],
#  ['ሰሞኑን', 'ደሞ', 'ክኒንህን', 'አልወሰድክም', 'አደል'],
#  ['አፌ',
#   'ቁርጥ',
#   'ይበል',
#   'ሄንዬ',
#   'ምን',
#   'ላርግህ',
#   'ንገርልኝ',
#   'መቼም',
#   'እውነትን',
#   'አይቀበሉ',
#   'እነዚ',
#   'መሳቂያወች'],
#  ['የማያስብ', 'አእምሮ', 'ደደብነት', 'ጭንቅላት', 'የተሸምክ', 'እርግጠኛ', 'ሆነሀል'],
#  ['አማራ',
#   'እኛ',
#   'ጋር',
#   'ለማኝ',
#   'ናቸው',
#   'አንድም',
#   'ትግረወይም',
#   'ኦሮሞ',
#   'ወደ',
#   'አማራ',
#   'ክልል',
#   'ለስራ',
#   'ፊለጋ',
#   'አይሄድም',
#   'ግን',
#   'አማራ',
#   'ለ',
#   'ቀን',
#   'ስራ',
#   'እስከ',
#   'ጅጅጋ',
#   'አወዳይገለምሶየኛን',
#   'እርሻ',
#   'በርካሽ',
#   'ይሰራሉ',
#   'ግን',
#   'ሰሞኑን',
#   'በደቡቢ',
#   'እየተቀየሩ',
#   'ነው'],
#  ['ኩሩ',
#   'ህዝብ',
#   'ኩሩ',
#   'ማንነት',
#   'ያለው',
#   'ህዝብ',
#   'ማንንም',
#   'መሆን',
#   'አይችልም',
#   'ራሱን',
#   'እንጂ',
#   'ዶተር',
#   'በፍቃዱ',
#   'ደግፌ',
#   'አጥምቀውህ',
#   'እንዲህ',
#   'ግራ',
#   'ያጋቡህ'],
#  ['ሄኒ',
#   'በርታ',
#   'ወንድሜ',
#   'ኦሮሞና',
#   'ትግሬ',
#   'ብቻ',
#   'ሳይሆን',
#   'ለሆድ',
#   'ያደረ',
#   'የትኛውም',
#   'አማራ',
#   'አማራ',
#   'እስካልሆነ',
#   'ድረስ',
#   'አይጠቅምም',
#   'አንተ',
#   'ብርቱ',
#   'ታጋይ',
#   'ነህ'],
#  ['ኦነግነትም', 'ሆነ', 'ህወሀትነት', 'ኩራት', 'መሆኑን', 'ባወክ', 'አንተ', 'ኩታራ', 'ቆምጬ'],
#  ['የሁሉም',
#   'ስህተት',
#   'ኢትዮጵያ',
#   'መሆን',
#   'አለመቻላቸው',
#   'ብቻ',
#   'ነው',
#   'አማራ',
#   'ኦሮሞም',
#   'ትግሬም'],
#  ['በተጨባጭም',
#   'አንዴ',
#   'ሸዋ',
#   'ነኝ',
#   'በሌላ',
#   'ጊዜ',
#   'የጎንደር',
#   'ዘር',
#   'አለብኝ',
#   'እያልክ',
#   'የምትፅፈው',
#   'በጭንቅ',
#   'ውስጥ',
#   'ያለህ',
#   'ሰው',
#   'ነህ',
#   'አንተ',
#   'ደግሞ',
#   'ያልበሰልክ',
#   'አቋም',
#   'የሌለህ',
#   'ራስህ',
#   'ዳር',
#   'ላይ',
#   'አስቀምጠህ',
#   'ንፁሀን',
#   'እሳት',
#   'ላይ',
#   'ለመማገድ',
#   'ቅስቀሳ',
#   'የምታደርግ',
#   'በእብደት',
#   'ውስጥ',
#   'የምትገኝ',
#   'ሰው',
#   'ነህ',
#   'ያበድክም',
#   'ይመስለኛል',
#   'ምንም',
#   'ብትል',
#   'ሰሚ',
#   'የለህም'],
#  ['አማራ',
#   'ብትሆን',
#   'ምን',
#   'የተለየ',
#   'ነገር',
#   'ታገኛለህ',
#   'ኦሮሞ',
#   'ወይም',
#   'ትግሬ',
#   'በመሆን',
#   'ምን',
#   'የምታጣው',
#   'ነገር',
#   'አለ',
#   'ሚልየን',
#   'የሚጠጋ',
#   'አማራ',
#   'ኦሮምያ',
#   'ውስጥ',
#   'ይኖራል',
#   'ለምን',
#   'ብለህ',
#   'ጠይቅ'],
#  ['በበታችነት', 'ስሜት', 'እንዳደግክ'],
#  ['ነገረ', 'ስራክ', 'እያሳወቀብክ', 'ነው'],
#  ['ኢትዮጵያዊነት',
#   'አይሰማቸዉ',
#   'ብትል',
#   'ያስከዳል',
#   'አማራ',
#   'ለመሆን',
#   'የምለዉ',
#   'አያስከድም',
#   'ሀገሩን',
#   'የሞላዉ',
#   'ተንከራታች',
#   'ማን',
#   'ሆነና',
#   'ነዉ',
#   'ሰዉ',
#   'ለመንከራተት',
#   'የምመኘዉ'],
#  ['አንተ',
#   'እንደዚህ',
#   'ጠላቶቻችንን',
#   'ስትታገል',
#   'ነው',
#   'የሚያምርብህ',
#   'አደራሀን',
#   'ሁለተኛ',
#   'ስለጎጥ',
#   'እንዳታወራ',
#   'ምንም',
#   'ችግር',
#   'ቢፈጠር',
#   'ተጎጅዎች',
#   'እኛ',
#   'ስለሆን',
#   'አንድ',
#   'ሆነን',
#   'መቆም',
#   'ነው',
#   'የሚያስፈልገው'],
#  ['ጣኦት',
#   'አምልኮን',
#   'ከሀያሉ',
#   'እግዚአብሄር',
#   'አምልኮ',
#   'በምስጋና',
#   'ስም',
#   'መቀላቀል',
#   'ከግለሰብ',
#   'ቢሆን',
#   'ግለሰቡ',
#   'እራሱን',
#   'ያዋርዳል',
#   'ይህ',
#   'ነገር',
#   'ታላቋን',
#   'እናት',
#   'ኢትዮጵያን',
#   'እመራለሁ',
#   'ከሚል',
#   'መንግስት',
#   'ሲሆን',
#   'ግን',
#   'ያሳፍራል',
#   'በዝች',
#   'አገርም',
#   'በራሳቸውም',
#   'መርገምት',
#   'ይጠራል'],
#  ['ለአማራ',
#   'ህዝብ',
#   'እኮ',
#   'ካንተ',
#   'ይልቅ',
#   'ኦነግ',
#   'ይሻለዋል',
#   'እኮ',
#   'ቢያንስ',
#   'ወደ',
#   'አንድነት',
#   'እየመጣ',
#   'ነው',
#   'አንተኮ',
#   'ለአማራ',
#   'ህዝብ',
#   'ህወሀት',
#   'ነህ',
#   'ሙቅ'],
#  ['ባልና',
#   'ሚስት',
#   'ከአንድ',
#   'ምንጫ',
#   'ይቀዳል',
#   'አይደል',
#   'የሚባለውሁለቱም',
#   'ከሰውነት',
#   'ጎዳና',
#   'የወጡ',
#   'ናቸው'],
#  ['ሾጥ',
#   'ያረግሀል',
#   'እንዴአማራ',
#   'ለመሆን',
#   'የኖሩና',
#   'የሚኖሩት',
#   'ኦባንግ',
#   'ሜቶና',
#   'ኦባንግ',
#   'ሜቶ',
#   'ናቸው'],
#  ['አማራ', 'ሚባል', 'ነገር', 'አለወይ', 'እስኪ', 'ተስማሙና', 'ንገሩን'],
#  ['እንዴ',
#   'ምን',
#   'ሆነክ',
#   'ነው',
#   'አማራ',
#   'መሆን',
#   'እኮ',
#   'መረገም',
#   'ነው',
#   'ትግሬ',
#   'እና',
#   'ኦሮሞ',
#   'በማንነቱ',
#   'መኩራት',
#   'እና',
#   'መኖር',
#   'የሚፈልግ',
#   'ጀግና',
#   'ነው',
#   'ለዚህም',
#   'ነው',
#   'በማንነቱ',
#   'ማይደራ',
#   'ደረው',
#   'ትግሬ',
#   'እና',
#   'ኦሮሞ',
#   'አሁንም',
#   'በማንም',
#   'ትላ',
#   'ስር',
#   'መኖር',
#   'አይፈልግም'],
#  ['አማራ',
#   'እንጂ',
#   'ወያኔ',
#   'እና',
#   'ኦነግ',
#   'ተላላኪ',
#   'ሁኖ',
#   'አይውቁም',
#   'በታሪክ',
#   'ከመጣ',
#   'አማራ',
#   'በጉራ',
#   'እንጂ',
#   'የኢትዮጵያ',
#   'መሪ',
#   'ሁኖ',
#   'አይውቅም',
#   'ያ',
#   'አለን',
#   'የምቱሉት',
#   'ሚኒልክ',
#   'እንካን',
#   'በአባቱ',
#   'ኦሮሞ',
#   'ነውየባታችነት',
#   'ስሜት',
#   'ሊሰማው',
#   'የሚገባው',
#   'አማራ',
#   'እንጂ',
#   'ትግራዋይ',
#   'አደለም'],
#  ['እስማማለሁ',
#   'ምልክቱ',
#   'ደግሞ',
#   'አቶ',
#   'ልደቱና',
#   'ቴድሮስ',
#   'ፀጋዬ',
#   'ባደረጉት',
#   'ውይይት',
#   'ተብራርቷል'],
#  ['ኦሮሞ', 'የድሮው', 'ስሙን', 'አትጥሩብኝ', 'ይላል', 'ያ', 'ዋናው', 'ማሳያ', 'ነው'],
#  ['አማራ', 'የሚባል', 'እኮ', 'የለም', 'ስለዚህ', 'የሌለን', 'ነገር', 'ለመሆን', 'እንዴት', 'ይመኛሉ'],
#  ['ምን',
#   'አደከመኝ',
#   'ፍካሬ',
#   'እየሱሰ',
#   'ተነግሮሀል',
#   'አሁንም',
#   'ሰሚኖች',
#   'ይገዛሉ',
#   'አማሮች',
#   'ነን',
#   'ባዬች',
#   'እርሰ',
#   'በርስ',
#   'የልቃሉ'],
#  ['እኔ',
#   'ፈጣሪን',
#   'እማመሰግነው',
#   'ከአማራና',
#   'ከኦርቶዶክስ',
#   'እምነት',
#   'ተከታዮች',
#   'ዘር',
#   'ስለፈጠረኝ',
#   'ነው'],
#  ['አማራነት', 'ከፈጣሬ', 'የተሰጠ', 'ነው', 'ምንም', 'ማድረግ', 'አይቻልም'],
#  ['ለመሆኑ',
#   'አማራ',
#   'የሚባል',
#   'ነገድ',
#   'እንደሌለ',
#   'አጠቃላይ',
#   'ምሁራኖች',
#   'ስምምነት',
#   'ላይ',
#   'በደረሱበት',
#   'ሁኔታ',
#   'አንተ',
#   'አማራ',
#   'የምትለው',
#   'ማንን',
#   'ይሆን'],
#  ['አህያ', 'ለመሆን', 'አትልም', 'ሰዉ', 'ነን', 'እና', 'አህያ', 'መሆንአንችልም'],
#  ['አቃቢ',
#   'ህጉ',
#   'የሰኔ',
#   'አስራምስቱን',
#   'ግድያ',
#   'አስመልክቶ',
#   'መግለጫ',
#   'እሰጣለሁ',
#   'ብሏል',
#   'ከዚያ',
#   'የሚቀድሙ',
#   'ጉዳዮች',
#   'ለህዝብ',
#   'ይፋ',
#   'ሆነዋል',
#   'ወይ',
#   'የመስቀል',
#   'አደባባዩ',
#   'ቦንብ',
#   'ፍንዳታ',
#   'የኢንጂነር',
#   'ስመኘው',
#   'ገዳይ',
#   'የቡራዩ',
#   'ጭፍጨፋ',
#   'የለገጣፎ',
#   'ወንጀል',
#   'የ',
#   'አባይ',
#   'ግድብ',
#   'ላይ',
#   'በሜቴክ',
#   'ተሰራ',
#   'የተባለው',
#   'የቢሊዮን',
#   'ብር',
#   'መጭበርበር',
#   'የተሰረቀ',
#   'አውሮጵላን',
#   'በጣም',
#   'ተያያዥ',
#   'መልስ',
#   'ያላገኙ',
#   'ዳህራይ',
#   'ወንጀሎች',
#   'በእንጥልጥል',
#   'በቀሩበት',
#   'የሰኔ',
#   'አስራምስቱ',
#   'ወንጀል',
#   'ለምን',
#   'ቅድሚያ',
#   'ተሰጠው'],
#  ['የመስቀል',
#   'አደባባዩ',
#   'ጌች',
#   'የእንጅነሩ',
#   'በጭንቀት',
#   'ራሱን',
#   'ወሰደ',
#   'ሲባል',
#   'የሰማሁ',
#   'መሰለኝ',
#   'ሌሎችን',
#   'አልሰማሁም'],
#  ['አቋም',
#   'የለህም',
#   'ሰውየው',
#   'አሁን',
#   'ይሄን',
#   'ብለህ',
#   'ከሰአት',
#   'ደግሞ',
#   'ምን',
#   'እንደምትል',
#   'አይታወቅምስለዚህ',
#   'አንድ',
#   'አቋም',
#   'ይኑርህ'],
#  ['ከቅርብ',
#   'ግዜ',
#   'ዎዲህ',
#   'የትግል',
#   'ስልቱ',
#   'እየገባህ',
#   'ይመስለኛል',
#   'በተሻለ',
#   'ደረጃ',
#   'ለመታገል',
#   'ዎቅቱ',
#   'የሚይቅ',
#   'አሰላለፍ',
#   'ይጠበቅብሀል',
#   'አንተ',
#   'በብዙዎች',
#   'ዘንድ',
#   'እውቅና',
#   'ስላለህ',
#   'እሱን',
#   'እደ',
#   'መልካም',
#   'አጋጣሚ',
#   'በመጠቀም',
#   'አማራን',
#   'አንቃበት'],
#  ['አማራ',
#   'ቁማሩን',
#   'ከተበላ',
#   'ቆየ',
#   'እኮ',
#   'አሁን',
#   'ሚስበው',
#   'ካርታ',
#   'እዬዬውን',
#   'ብቻ',
#   'ነው',
#   'ደግሞ',
#   'ለማልቀስ',
#   'ከእናንተ',
#   'ወድያ',
#   'ሰኔ',
#   'ሰው',
#   'ሳይሆን',
#   'ሀገር',
#   'ነው',
#   'የተገደለችው',
#   'ለዚህ',
#   'ደግሞ',
#   'አቃቢ',
#   'ህግ',
#   'ብቻ',
#   'ሳይሆን',
#   'እኛም',
#   'እንጠይቃለን',
#   'አማራ',
#   'እኮ',
#   'ለስንዝር',
#   'መሬት',
#   'እናቱን',
#   'አባቱን',
#   'ወንድሙን',
#   'የሚገል',
#   'ህዝብ',
#   'ነው',
#   'አይዞህ',
#   'ተፈጥሮ',
#   'ነው'],
#  ['አማራ',
#   'አንድ',
#   'ከሆነ',
#   'ፀረአማራው',
#   'ሁሉ',
#   'ወደ',
#   'መቃብሩ',
#   'ይወርዳልአሁ',
#   'እራሰችሁን',
#   'የኢትዮጵያን',
#   'መሪ',
#   'አድርጋችሁኮ',
#   'ነው',
#   'የምትመለከቱት'],
#  ['የትል',
#   'የህል',
#   'እንኳ',
#   'አቅም',
#   'በኢትዮጵያ',
#   'ቦታ',
#   'የላችሁምአሁ',
#   'እራሰችሁን',
#   'የኢትዮጵያን',
#   'መሪ',
#   'አድርጋችሁኮ',
#   'ነው',
#   'የምትመለከቱት'],
#  ['የትል', 'የህል', 'እንኳ', 'አቅም', 'በኢትዮጵያ', 'ቦታ', 'የላችሁም'],
#  ['እዲህ', 'ነው', 'ሄኒ', 'አንድነትን', 'መስበክ', 'በርታልን'],
#  ['ሄኖክ',
#   'የሽ',
#   'ጥላ',
#   'እረ',
#   'ምን',
#   'ላድርግህ',
#   'አንተኮ',
#   'ባጭሩ',
#   'ምንጡቅ',
#   'አይምሮ',
#   'ነው',
#   'ያለህ',
#   'ሌላ',
#   'አልልም',
#   'አንድ',
#   'አምላክ',
#   'ይጠብቅህ',
#   'ሀላስ'],
#  ['እንደዛሬ',
#   'የውስጤን',
#   'አውጥህ',
#   'ተናግረህልኝ',
#   'አታቅም',
#   'ሄኖኬ',
#   'እግዚያብሄር',
#   'ይስጥህ',
#   'እንደዚህ',
#   'አይነት',
#   'ወደ',
#   'አንድነት',
#   'የሚመራ',
#   'ፅሁፎችን',
#   'ሰትፅፉ',
#   'ህዝቡም',
#   'አንድ',
#   'ይሆናል'],
#  ['ትትክክልተማርአማራያለፈዉይብቃንበመገድየወደቀችአማራአራግፈንአፍሯንመሸክፍአልብንወድማላምሄኖክየሰላሙጌታካትጋርይሆንአነቃቃንደንዘናልበምናያቸዉነገርብዛት'],
#  ['ጀግና', 'ነህ', 'ባለህበት', 'ድንግልማሪያም', 'ትጠብቅህ'],
#  ['በብዥታ', 'ስተት', 'መስራትን', 'ማመን', 'ትልቅነት', 'ነው'],
#  ['ቅድሚያ',
#   'ለሚሰጠው',
#   'ችግር',
#   'ቅድሚያ',
#   'እንስጥ',
#   'ማለትህም',
#   'ዝቅ',
#   'ብለህ',
#   'ምክር',
#   'መቀበልህን',
#   'ያመለክታል'],
#  ['ትክክል',
#   'አማራን',
#   'ሰላም',
#   'መንሳት',
#   'የታቀደ',
#   'ነውበቅርብ',
#   'ቀን',
#   'ክልላችን',
#   'ውስጥ',
#   'ችግር',
#   'ይፈጠራልየክልሉ',
#   'ህዝብ',
#   'መረጋጋት',
#   'አለበት',
#   'በተጨማሪም',
#   'መደራጀትበሁሉም',
#   'ነገር',
#   'ያገባኛል',
#   'የሚል',
#   'ስሜት',
#   'መቅረት',
#   'አለበትኢትዮጵያ',
#   'የሚል',
#   'አስተሳሰብ',
#   'ጥሩ',
#   'ቢሆንምበአሁኑ',
#   'ሰአት',
#   'የሚያዋጥን',
#   'አማራ',
#   'ብቻ',
#   'ነው'],
#  ['በትክክልምንምይባልምን', 'አማራነታችን', 'በአንድ', 'ድምፅ', 'ወደፊት'],
#  ['የአምሀራ',
#   'ህዝብ',
#   'ላይ',
#   'ነን',
#   'ከዚህ',
#   'በ',
#   'ሀላ',
#   'ለማንም',
#   'አንሸወድም',
#   'ነቋ',
#   'ብለናል'],
#  ['አዴፓዎች',
#   'ተዋናይ',
#   'ይሆናሏዳዲስ',
#   'አጀንዳዎች',
#   'በመስጠት',
#   'ይባላሉ',
#   'ብሎ',
#   'ማሰብ',
#   'ብሽቅነት',
#   'ነውሰብረናቸዋል',
#   'ተብለን',
#   'የለ',
#   'እኛም',
#   'ስብራታችንን',
#   'እያስታመምን',
#   'አንኖርምነው',
#   'ስብራታችንን',
#   'ዳግም',
#   'እንዲደገም',
#   'ፈልገው',
#   'ነውፀሎት',
#   'ላይ',
#   'ነን',
#   'በላቸውመግለጫችሁን',
#   'የምንሰማበትና',
#   'የምናይበት',
#   'ጊዜ',
#   'የለንምከፈለጋችሁ',
#   'ለጀዋር',
#   'አንብቡለት'],
#  ['የአማራ',
#   'ህዝብ',
#   'እነኳን',
#   'አሁን',
#   'ማነነታቸው',
#   'ግልፅ',
#   'ብሎ',
#   'በወጣበት',
#   'ያኔም',
#   'ገብቶታል',
#   'አነድ',
#   'አማራራራራራራራራ'],
#  ['ግድ',
#   'የለም',
#   'በአማራ',
#   'ክልል',
#   'የተፈፀሙ',
#   'ጭፍጨፋ',
#   'እና',
#   'ወንጀሎችንም',
#   'ጥቀስ',
#   'አንተ',
#   'እየጮኸ',
#   'ትጠፋለህ',
#   'እንጂ',
#   'ስም',
#   'በማጥፋት',
#   'የሚጠፋ',
#   'ኦሮሞነት',
#   'የለም'],
#  ['የአማራ',
#   'ህዝብ',
#   'ሆይ',
#   'የሚሰጠውን',
#   'መግለጫ',
#   'እንዳትቀበሉት',
#   'አማራን',
#   'ለመከፋፈል',
#   'የሚሰጥ',
#   'መግለጫ',
#   'ነው'],
#  ['ይሄንን',
#   'ሴራ',
#   'እና',
#   'ደባ',
#   'ሊሞግት',
#   'የማይችል',
#   'ልፍስፍስ',
#   'አሽከር',
#   'ሆድ',
#   'አደር',
#   'አዴፓ',
#   'የሚባል',
#   'አፉኝት',
#   'እያለ',
#   'መቼም',
#   'ከስህተት',
#   'መማር',
#   'መንቃት',
#   'የሚባል',
#   'ነገር',
#   'የለም',
#   'ወሬ',
#   'አሳምሮ',
#   'ማውራት',
#   'ለማንም',
#   'ቀላል',
#   'ነው'],
#  ['የአማራ',
#   'ክልል',
#   'ፖርቲዎች',
#   'ህብረት',
#   'መፍጠር',
#   'ያልተመቸው',
#   'ኦነግ',
#   'መራሹ',
#   'ኢህአዴግ',
#   'ክልሉ',
#   'ግጭት',
#   'ውስጥ',
#   'እንዲገባ',
#   'ህዝቡ',
#   'እርስበርሱ',
#   'እንዲጋጭ',
#   'አልሞ',
#   'እየሰራ',
#   'ይመስለኛል'],
#  ['እውነት', 'ነው', 'ማንም', 'በዚህ', 'የሀሰት', 'መግለጫ', 'መከፋፈል', 'የለብንም'],
#  ['አቃቢ',
#   'ህግም',
#   'በብሄር',
#   'ሸንሽኖ',
#   'መሆን',
#   'አለበት',
#   'መግለጫ',
#   'የሚሰጠን',
#   'ዘይገርም',
#   'አሉ',
#   'አባ'],
#  ['ትክክል',
#   'ብልጥ',
#   'ከአንድ',
#   'በላይ',
#   'አይበልጥ',
#   'እንዲሉ',
#   'የእስከዛሬው',
#   'ይበቃል',
#   'በሰኔ',
#   'ችግር',
#   'ስንት',
#   'ንፁሀን',
#   'ወንድሞቻችብ',
#   'ታስረው',
#   'እያለ',
#   'አሁን',
#   'ደግሞ',
#   'የፌዴራል',
#   'አቃቤ',
#   'ህግ',
#   'ዛሬ',
#   'ሊሰጥ',
#   'ያሰበው',
#   'መግለጫ',
#   'አላማው',
#   'ምን',
#   'እንደሆነ',
#   'ግልፅ',
#   'ነው',
#   'ስለዚህ',
#   'ከዚህ',
#   'በኋላ',
#   'አይናችሁን',
#   'ጨፍናችሁ',
#   'ላሞኛችሁ',
#   'የህፃናት',
#   'ጨዋታ',
#   'ነው',
#   'ነገርዮው'],
#  ['ይህ', 'እኮ', 'የተለመደ', 'ነው', 'አማራውን', 'እረፍት', 'መንሳት', 'ነው', 'ወንድሜ', 'ሆዬ'],
#  ['እንናንተ',
#   'ስታራግቡ',
#   'የከረማችሁት',
#   'የሎችን',
#   'አራግባችሁ',
#   'ጨርሳችሁ',
#   'ነበርወይስ',
#   'እኛ',
#   'ብቻ',
#   'ስለሰኔ',
#   'ቱ',
#   'ዋሸተን',
#   'እንቅር',
#   'እውነት',
#   'አይውጣ',
#   'ነማለት',
#   'ነውለማንኛውም',
#   'መንግስትም',
#   'የነበሩ',
#   'ሰወችም',
#   'እውነቱን',
#   'ይንገሩእኛ',
#   'በፌስቡክ',
#   'የውሸት',
#   'ወሬ',
#   'የማንበከል',
#   'ሰወች',
#   'በመንግስት',
#   'የተጣራውን',
#   'ትክክለኛ',
#   'ወሬ',
#   'መስማትና',
#   'ማወቅ',
#   'እንፈልጋለንእውነት',
#   'ሲመጣ',
#   'ውሸት',
#   'ትጨነቃለችይላሉ',
#   'አባቶ'],
#  ['ሚሻለውም',
#   'ይሄው',
#   'ነው',
#   'ጠርዝና',
#   'ጠርዝ',
#   'ቆሞ',
#   'መሰዳደቡ',
#   'ለማንም',
#   'አይጠቅምም',
#   'አንድ',
#   'አማራ',
#   'ለሁሉም',
#   'አማራ',
#   'ሁሉም',
#   'አማራ',
#   'ለአንድ',
#   'አማራ'],
#  ['ግልፅ', 'ነው', 'የአማራ', 'ታጋዮችን', 'ለመከፋፈል', 'የታለመ', 'ነው'],
#  ['ታድያ',
#   'ስትበሳጭ',
#   'ዋጥ',
#   'እያደረጉ',
#   'ነው',
#   'ሄኖክ',
#   'እንዳትንደው',
#   'ህዝብህ',
#   'አዋቂ',
#   'ስለሆ',
#   'ለምን',
#   'ወዴት',
#   'ብሎ',
#   'ሊደነቃቀፍ',
#   'ይችላል'],
#  ['የስመኘው', 'ገዳይ', 'እራሱ', 'ስመኘው', 'ነው'],
#  ['ገዛኢ', 'አብረሀ', 'እና', 'ሰአራ', 'መኮንን'],
#  ['ከ',
#   'የባንክ',
#   'ቅርንጫ',
#   'የተዘረፈው',
#   'የህዝብ',
#   'ገንዘብ',
#   'ስንት',
#   'እንደሆነ',
#   'አልነገሩንም',
#   'ሰንቱ',
#   'ተዘርዝሮ',
#   'ያልቃል',
#   'የነሱ',
#   'ጉድውሸት',
#   'አተ',
#   'ስለአማራ',
#   'አድነት',
#   'ውነትአሳስቦህ',
#   'አተ',
#   'አዱ',
#   'የጃዋር',
#   'ሚስጥራውይ',
#   'ተከፋይ',
#   'አደለህ',
#   'ስለአማራ',
#   'በምን',
#   'ህሌናህ',
#   'ነውየምትናገረው',
#   'በዶላር',
#   'ህሌናህ',
#   'ከሆነ',
#   'ልትናገር',
#   'ትችል',
#   'ይሆናል'],
#  ['የጅሎቹ',
#   'ድራማ',
#   'ይቀጥላል',
#   'መቼም',
#   'አያፍሩምና',
#   'ትንሽ',
#   'ያስቁን',
#   'ተዋቸው',
#   'ግም',
#   'ለግም',
#   'አብሮ',
#   'ያዝግም',
#   'ነዉና'],
#  ['አማራን',
#   'እርስ',
#   'በራሱ',
#   'ለማባላትና',
#   'ኦሮሞ',
#   'ውስጥ',
#   'የተደረግውን',
#   'አፀያፊ',
#   'ግደይ',
#   'ትኩረት',
#   'እያዳደረግ',
#   'ትኩረቱን',
#   'ለማስቀየር',
#   'ነው',
#   'ይፋ',
#   'አደርጋለሁ',
#   'ያለው',
#   'አማራ',
#   'ከመቸውም',
#   'ግዜ',
#   'በላይ',
#   'አሁን',
#   'ችግር',
#   'ውስጥ',
#   'ገብተናል',
#   'እንደራጅ',
#   'እንደራጅ',
#   'እንደራጅ'],
#  ['ጎንደሮች', 'በግፍ', 'ተጨፍጭፈው', 'እውነቱ', 'እንዳይወጣ', 'ተቅበጠበጣችሁ'],
#  ['ሞኝ',
#   'ሰው',
#   'ሁለቴ',
#   'በባብይነደፋል',
#   'አንዴም',
#   'ሳያይ',
#   'ሁለተኛ',
#   'ለሰው',
#   'ሲያሳይ',
#   'እኛም',
#   'እደሰውየዉ',
#   'ሁለቴ',
#   'መሸወድ',
#   'የለብንም',
#   'ንቃ',
#   'አማራ'],
#  ['በሚገባ', 'ተነቃቅተናል', 'ይልቅ', 'ጎረቤቶቻችን', 'የትግራይ', 'አክቲቪስቶችም', 'መምሸቱን', 'እወቁ'],
#  ['እውነት', 'ነው', 'ሌላ', 'ድራማ', 'ሊሰሩብን', 'ስለፈለጉ', 'ነው'],
#  ['ሴራውን', 'ተረድተናል', 'አነድ', 'አማራ', 'ጠላቶች'],
#  ['አማራውእራስበእራሷይጣላምአንድነታችንለዘላቄይቀጥላልአንድነታችንንማንምአያፈረሰውምፈጣራያግዘናል'],
#  ['የእነጄነራልሰአረየግድያሁኔታምንሚክኒያትይቀርብለትይሆንጠባቅውበቅምተነሳስቶነውእንዳይሉፈራሁኝአብየትቀብራችሁ'],
#  ['አ',
#   'ን',
#   'ተ',
#   'ሌ',
#   'ባ',
#   'ነ',
#   'ህም',
#   'ን',
#   'ለ',
#   'መ',
#   'ግ',
#   'ለ',
#   'ፅ',
#   'እ',
#   'ደ',
#   'ፈ',
#   'ለ',
#   'ክ',
#   'ግ',
#   'ል',
#   'ፅ',
#   'ነውአ',
#   'ማ',
#   'ሀ',
#   'ራ',
#   'ነው',
#   'ስ',
#   'ተ',
#   'ቱ',
#   'ን',
#   'የ',
#   'ሰ',
#   'ራ',
#   'ው',
#   'ለ',
#   'ማ',
#   'ለ',
#   'ት',
#   'ነውት',
#   'ግ',
#   'ሬ',
#   'ነ',
#   'ህ'],
#  ['ስመኘው', 'ራሱ', 'ገደለ', 'ተባልክ', 'አደለ', 'እንዴ'],
#  ['ምነው',
#   'የቅማንትን',
#   'የወሎ',
#   'ከሚሴንና',
#   'የጉሙዙን',
#   'የጅምላ',
#   'ጭፍጨፋ',
#   'በጎጃም',
#   'የዶክተሮቹን',
#   'በድንጋይ',
#   'ተወግረው',
#   'ግድያ',
#   'በጎንደር',
#   'ነዋሪ',
#   'ትግሬዎችን',
#   'ዘርፎ',
#   'ማባረርን',
#   'ምስኪን',
#   'ሹፌር',
#   'ገድለው',
#   'ወደ',
#   'ትግራይ',
#   'የሚሄዱትን',
#   'መኪናዎች',
#   'የዘረፉትነሳ',
#   'ሳትጠቅስ',
#   'የእነሱ',
#   'ነብስ',
#   'የቁጫጭ',
#   'ነብስ',
#   'ነበር',
#   'እንዴ'],
#  ['ስህተትን', 'አምኖ', 'ለወደፊት', 'መጠንቀቅ', 'አለብን', 'ማለት', 'ትልቅነት', 'ነው'],
#  ['እነ',
#   'ቅቤው',
#   'ደግሞ',
#   'በልጣችሁን',
#   'ሳይሆን',
#   'በቅንነታችን',
#   'ገብታችሁ',
#   'አንዴ',
#   'ሸውዳችሁናልና',
#   'ከዚህ',
#   'በሗላ',
#   'አትድከሙ'],
#  ['አንተ', 'ራስህ', 'ሰይጣናዊ', 'ተልእኮ', 'የተሰጠህ', 'ፀረ', 'አማራ', 'አንድነት', 'ነህ'],
#  ['አዎ',
#   'በጎጃም',
#   'በድንጋይ',
#   'ተወግሮ',
#   'የተገደሉትን',
#   'እና',
#   'የቅማንት',
#   'ህዝብ',
#   'ጭፍጨፋን',
#   'መንሳት',
#   'አትፈልግምምን',
#   'አይነት',
#   'ጠባብ',
#   'ነህ'],
#  ['የረሳክ',
#   'ነገር',
#   'አለ',
#   'ስለ',
#   'ቤንሸንጉል',
#   'ጉሙዝ',
#   'ህፃናቸትና',
#   'የቅማንት',
#   'ህዝብ',
#   'ጭፍጨፋ',
#   'ጨፍጫፍዎችሁ',
#   'እናንተ',
#   'ስለሆናችሁ',
#   'ነዉ',
#   'የረሳክ'],
#  ['መታወቅ',
#   'ያለበት',
#   'ነገር',
#   'ግብጥ',
#   'እና',
#   'ሱዳን',
#   'ኢትዮጵያን',
#   'ሊያጠቁ',
#   'ቢነሱ',
#   'የ',
#   'አብይ',
#   'ወታደር',
#   'ሆኘ',
#   'ላገሬ',
#   'እንደምሞት',
#   'ግብጥ',
#   'እና',
#   'ሱዳን',
#   'ኢትዮጵያን',
#   'ሊያጠፉ',
#   'ቢነሱ',
#   'አብይ',
#   'በሚፈልገው',
#   'ነገር',
#   'ሁሉ',
#   'ከጎኑ',
#   'እንደምቆም',
#   'ምክኛቱም',
#   'ኢትዮጵያዊነትን',
#   'የሚበልጥ',
#   'ነገር',
#   'ስለሌለ',
#   'እና',
#   'ምን',
#   'ለማለት',
#   'ነው',
#   'ግብጦች',
#   'ሲያጣድፉት',
#   'በሴራ',
#   'ገልብጬው',
#   'ስልጣን',
#   'ልያዝ',
#   'የሚል',
#   'ልብ',
#   'የለኝም',
#   'የጀግና',
#   'ልብ',
#   'ነው',
#   'ያለኝ',
#   'ጀግና',
#   'ደሞ',
#   'አጋጣሚዎችን',
#   'ታኮ',
#   'አይደለም',
#   'የሚያሸንፈው',
#   'እና',
#   'ምን',
#   'ለማለት',
#   'ነው',
#   'አብይን',
#   'አልደግፈውም',
#   'የሚሰራው',
#   'ልክ',
#   'እንዳልሆነ',
#   'ይሰማኛል',
#   'አብይ',
#   'እና',
#   'ግብጥን',
#   'ግን',
#   'ለማነፃፀር',
#   'እና',
#   'የፖለቲካ',
#   'ጥቅም',
#   'ለማግኘት',
#   'ከግብጥ',
#   'ስር',
#   'ሄደው',
#   'እንደተወሸቁት',
#   'ህወሀቶች',
#   'የባንዳነት',
#   'ታሪክ',
#   'የለኝም',
#   'አማራ',
#   'ነኛ'],
#  ['ይች',
#   'የክፍያ',
#   'ፖለቲካ',
#   'ደግሞ',
#   'ታስቃለች',
#   'አቶ',
#   'ግርማ',
#   'ህሊና',
#   'በኖረውና',
#   'በቀመሳት',
#   'ገንዘብ',
#   'የሚፈልግማ',
#   'ከእነ',
#   'ቴዎድሮስ',
#   'አድሀኖም',
#   'ጋር',
#   'ልኡክ',
#   'ሆኖ',
#   'ነው',
#   'መሄድ',
#   'ያለበት'],
#  ['ለግርማ',
#   'ሰይፉና',
#   'ግብረአበሮቹ',
#   'የፖለቲካ',
#   'ነጋዴዎች',
#   'መልስ',
#   'በመስጠት',
#   'ጊዜህን',
#   'አትግደል',
#   'አንተ',
#   'ድምፅ',
#   'እንድትሆናቸው',
#   'የሚፈልጉ',
#   'ብዙሀን',
#   'እየጠበቁህ',
#   'ነው'],
#  ['ይሄን',
#   'እና',
#   'ስለ',
#   'ፓይለት',
#   'ዮሀንስ',
#   'የተፃፈውን',
#   'ግርማ',
#   'ሰይፉ',
#   'ፃፈው',
#   'ብየ',
#   'ለማመን',
#   'ከበደኝ',
#   'ምናልባት',
#   'አካውንቱ',
#   'ሀክ',
#   'ተደርጎ',
#   'ይሆን',
#   'ፅፎት',
#   'ከሆነ',
#   'ግን',
#   'ከዚህ',
#   'በላይ',
#   'ውርደት',
#   'የለም'],
#  ['አስደንግጦኛልአሳዝኖኛልአፍሬበታለሁበጣም', 'ያሳዝናል'],
#  ['ፓርላማ',
#   'ተወክሎ',
#   'ገብቶ',
#   'የነበረው',
#   'ይሄ',
#   'ሰው',
#   'ነው',
#   'ምኑ',
#   'ማፈሪያ',
#   'ነው',
#   'አበስኩ',
#   'ለምን',
#   'ግን',
#   'አማራው',
#   'ሲደራጅ',
#   'እና',
#   'እራሱን',
#   'ለመከላከል',
#   'ጥረት',
#   'ሲያደርግ',
#   'አዳሜ',
#   'ከየጎሬው',
#   'እየወጣ',
#   'የሚንጫጫው',
#   'ትዝብት',
#   'ነው'],
#  ['ላንተና',
#   'ለሌሎች',
#   'ተቺዎች',
#   'የማይመጥን',
#   'ምላሽ',
#   'ከመስጠት',
#   'በየቦታው',
#   'የቀድሞው',
#   'ብቸኛ',
#   'የተምክር',
#   'ቤት',
#   'አባል',
#   'እያለ',
#   'ለሚፎክርበት',
#   'በኢሳት',
#   'ያስመረጥነው',
#   'እኛ',
#   'ነን',
#   'ላለው',
#   'የቀድሞ',
#   'ደህንነት',
#   'አባል',
#   'መልስ',
#   'በሰጠ',
#   'ነበር',
#   'ኢሳትም',
#   'በተደጋጋሚ',
#   'ሲያቀርበው',
#   'ይህችን',
#   'ያለመጠየቁ',
#   'ትዝብት',
#   'ላይ',
#   'ጥሎታል'],
#  ['ጌቾ', 'ይሄን', 'ተወው', 'ወሬያም', 'በለውአሁን', 'እሱ', 'ህብረ', 'ብሄራም', 'ኮኖ', 'ነው'],
#  ['በጭንቅላት', 'ሳይሆን', 'በሆዱ', 'ከሚያስብ', 'ጋር', 'ለምን', 'ጀመርከው'],
#  ['ማወቅ',
#   'ማለትፊደል',
#   'በቆጠረ',
#   'እንዳልሆነ',
#   'ይገባኝ',
#   'እሱ',
#   'በየጊዜ',
#   'የሚሰጣቸው',
#   'የተለያዩ',
#   'ሀሳቦች',
#   'ነውበአንድ',
#   'ነገር',
#   'ላይ',
#   'አንድ',
#   'አቋም',
#   'ነው',
#   'የሚጠበቀው',
#   'ትክክልም',
#   'ባይሆን'],
#  ['የሆነ',
#   'ግዜ',
#   'ላይ',
#   'መስፍን',
#   'ወልደማርያም',
#   'የ',
#   'ምርጫ',
#   'ግዜ',
#   'እንዲያው',
#   'በእድል',
#   'ያሸነፈ',
#   'ሰው',
#   'ነው',
#   'ብለውት',
#   'እየየ',
#   'እያለ',
#   'ነበር',
#   'እና',
#   'ይሄ',
#   'ሰውየ',
#   'በዚያ',
#   'ምርጫ',
#   'በእድል',
#   'ፓርላማን',
#   'ስለተቀላቀለ',
#   'ብቻ',
#   'ራሱን',
#   'የምክንያታዊነትና',
#   'የፓለቲከኛ',
#   'ጥግ',
#   'አድርጎ',
#   'ነው',
#   'የሚቆጥር',
#   'ከሚፅፋቸው',
#   'ፅሁፎችና',
#   'ከሚናገራቸው',
#   'ንግግሮች',
#   'እንደምንረዳው',
#   'ግን',
#   'ያው',
#   'ደነዝ',
#   'ነገር',
#   'ነው',
#   'በአማራ',
#   'ጉዳይ',
#   'ደግሞ',
#   'እሱና',
#   'አቤ',
#   'ቶኪቾው',
#   'አንድ',
#   'ናቸው',
#   'አማራና',
#   'የአማራን',
#   'የመጥላትና',
#   'የማጣጣል',
#   'አባዜ',
#   'አለባቸው',
#   'ለማንኛውም',
#   'ግን',
#   'አንተን',
#   'ምንም',
#   'አይሰማህ',
#   'ሚዲያዎችም',
#   'የዚህን',
#   'ሰውየ',
#   'ተራ',
#   'አቋም',
#   'በመረዳት',
#   'የሚሰጡትን',
#   'ቦታና',
#   'ክብር',
#   'ሊነፍጉት',
#   'ይገባል'],
#  ['ብልሹ',
#   'የትግሬ',
#   'ልጅ',
#   'ነው',
#   'የገርመውና',
#   'ደሞስ',
#   'አንተን',
#   'ብሎክ',
#   'የሚያደረግ',
#   'እሱ',
#   'መጀመሪያ',
#   'ካንተ',
#   'ጋ',
#   'ቀርቶ',
#   'ተከታይም',
#   'የለው',
#   'ይህ',
#   'ወራዳ',
#   'ትግሬ',
#   'ሳይሆን',
#   'አይቀርም',
#   'ግን',
#   'ይህ',
#   'አሳማ',
#   'ባሪያ',
#   'ወራዳ',
#   'ብሄርተኝታችን',
#   'ላይ',
#   'ብቻ',
#   'አተኩርማ',
#   'አቦ'],
#  ['የእናንተ', 'አጉል', 'እልህ', 'መገባባት', 'ደግሞ', 'ያስጠላል', 'ኤጭ'],
#  ['ይሄን', 'ትንሽ', 'ጉማሬ', 'ሰምቶ', 'እንዳልሰማ', 'ማለፍ', 'ነው', 'እንጂ'],
#  ['አቶ',
#   'ግርማ',
#   'ከወያኔ',
#   'ደህንነት',
#   'መስሪያቤት',
#   'እጅ',
#   'እና',
#   'ጓንት',
#   'ሁኖ',
#   'የሚሰራ',
#   'ሌባ',
#   'ነው'],
#  ['እንዲህ', 'የወረደ', 'ሰው', 'ነው'],
#  ['ይህ',
#   'ቆሻሻ',
#   'ለካስ',
#   'ተኩላ',
#   'ነበር',
#   'ያላሰበው',
#   'ማእበል',
#   'መቶ',
#   'ስላዳፈነው',
#   'ግራ',
#   'ገበው'],
#  ['የግርማ',
#   'ፓለቲካ',
#   'ሆድን',
#   'በታሳቢነት',
#   'እና',
#   'እናቴን',
#   'ያገባ',
#   'የሚል',
#   'መሆኑን',
#   'የ',
#   'ምርጫ',
#   'ላይ',
#   'ጭራውን',
#   'ሲቆላ',
#   'ታዝበን',
#   'ወቶልናል',
#   'ዛሬ',
#   'እንዳዲስ',
#   'የሚያወራው',
#   'ጎርፍ',
#   'አመጣሹ',
#   'ያልገባው',
#   'እስኪገባው',
#   'መሆኑ',
#   'ነው',
#   'ችግሩ'],
#  ['የተደበቀ',
#   'የአማራ',
#   'ያለበት',
#   'መሆኑ',
#   'በግልፅ',
#   'ያስታውቃል',
#   'ወያኔ',
#   'በአማራ',
#   'ላይ',
#   'ያደረገውን',
#   'ነገር',
#   'በሙሉ',
#   'እንደሚደግፍ',
#   'ይህ',
#   'ፎቶ',
#   'ላይ',
#   'የፃፈው',
#   'መልእክት',
#   'ገላጭ',
#   'ነው',
#   'በአማራ',
#   'በደልና',
#   'መገፋት',
#   'ላይ',
#   'እየተሳለቀ',
#   'ነው'],
#  ['ግርማ',
#   'መልካም',
#   'ነገር',
#   'ቢናገር',
#   'ነበር',
#   'የሚገርመኝ',
#   'ምክንያቱም',
#   'መርካቶ',
#   'ውስጥ',
#   'ኪስ',
#   'እያወለቀ',
#   'እንዳደገ',
#   'ስለማውቅ',
#   'በነገራችሁ',
#   'ላይ',
#   'አማራ',
#   'እንዳይመስላችሁ',
#   'አደራ',
#   'በአንደበቱ',
#   'ኦሮሞ',
#   'ነኝ',
#   'ብሎ',
#   'ሲናገር',
#   'ሰምቸዋለሁ',
#   'ስለዚህ',
#   'አሁን',
#   'ፊንፊኔ',
#   'ከኛ',
#   'ብየ',
#   'እጠቀማለሁ',
#   'ከሚል',
#   'እሳቤ',
#   'ተነስቶ',
#   'ነው',
#   'አማራ',
#   'ላይ',
#   'ቅርሻቱን',
#   'የሚተፋው'],
#  ['የመጨረሻ', 'ማፈሪያ', 'ነው'],
#  ['በእርግጠኝነት',
#   'ሰክሮ',
#   'የፃፈዉ',
#   'መሆን',
#   'አለበትእስኪ',
#   'ይህ',
#   'ብለህ',
#   'ነበር',
#   'ተብሎ',
#   'ይጠየቅ',
#   'እና',
#   'መቼአላልኩም',
#   'ብሎ',
#   'ይክዳልይሄ',
#   'ማጣበቂ',
#   'ፓርላማ',
#   'ዉስጥ',
#   'ተቃዋሚ',
#   'መስሎ',
#   'የነ',
#   'መለስ',
#   'እስስት',
#   'አልነበረምዶማ'],
#  ['ትልቅ', 'ሰው', 'አይደለም', 'እንዴ', 'ሰውየውምን', 'ሆኖ', 'ነው', 'እንደ', 'ገለባ', 'ቀለለ'],
#  ['ጌቾ',
#   'ግርማ',
#   'ሰይፉ',
#   'ሰው',
#   'ሆኖ',
#   'በመፈጠሩ',
#   'ሰው',
#   'እንበለው',
#   'እንጂ',
#   'ሰው',
#   'የሚባል',
#   'አይደለም',
#   'አንተ',
#   'ከናሳኸው',
#   'ጉዳይ',
#   'ሌላ',
#   'የፓለቲካ',
#   'እስረኞችን',
#   'ምግብ',
#   'አበላሁ',
#   'ብሎ',
#   'የፃፈውን',
#   'አስታውሳለሁ',
#   'እጅግ',
#   'ሲበዛ',
#   'ግብዝና',
#   'ደንበኛ',
#   'የፓለቲካ',
#   'ነጋዴ',
#   'ነው',
#   'ደግሞ',
#   'በሀገራችን',
#   'ፓለቲከኛ',
#   'ተብለው',
#   'እስር',
#   'ቤትን',
#   'ከማያውቁት',
#   'አስመሳይ',
#   'ተቃዋሚዎች',
#   'አንዱ',
#   'ስለሆነ',
#   'በፓለቲካ',
#   'አመለካከት',
#   'ብቻ',
#   'የሚደርሰውን',
#   'መከራ',
#   'አያውቀውም'],
#  ['ይሄ', 'ደንቆሮ', 'አማርኛን', 'እንዴት', 'እንደሚጫወትበት', 'አይተህልኛል'],
#  ['ተወው', 'ባክህ', 'ይህን', 'ልጥልጥ', 'ባሪያ', 'አቴንሽን', 'ፍለጋ', 'እየተፍጨረጨረ', 'ነው'],
#  ['ይሄ',
#   'ተራ',
#   'ተሳዳቢ',
#   'ነበር',
#   'ህዝብ',
#   'ወክሎ',
#   'አምስት',
#   'አመት',
#   'የተዘፈዘፈውየሱን',
#   'ጉድ',
#   'ለማወቅ',
#   'የአቶ',
#   'አያሌውን',
#   'ኢንተርቪው',
#   'ማዳመጥ',
#   'በቂ',
#   'ነው'],
#  ['አቅም', 'ካለውና', 'በሀሳብ', 'መሞገት', 'ከቻለ', 'ማድረግ', 'አልነበረበትምናቀው'],
#  ['ግርማ', 'ከፍያ', 'ይሰራ', 'ነበር', 'አይደል', 'ሁሉም', 'ስው', 'እንደእሱ', 'ይመለዋል'],
#  ['አማራን',
#   'ያላወቃችሁ',
#   'ሰወች',
#   'እያየሁ',
#   'ነው',
#   'አማራ',
#   'ማለት',
#   'ነፍጠኛ',
#   'መመከት',
#   'እሚችል',
#   'እማይዋሽ',
#   'እስካሁን',
#   'ስለ',
#   'ኢ',
#   'ት',
#   'የኖረ',
#   'ህዝብ',
#   'ነው',
#   'በቃ',
#   'በዛ',
#   'አልበዛም'],
#  ['አንቀህ',
#   'ያዝከው',
#   'ደነገጠ',
#   'በህዝብም',
#   'አላገጠ',
#   'ይህ',
#   'እብደት',
#   'ነው',
#   'እኮ',
#   'እኛ',
#   'ግን',
#   'ስንቶቹን',
#   'ተሸክመን',
#   'እንደኖርን',
#   'ነው',
#   'የሚያሳየን',
#   'ስንቱን',
#   'ጠላት',
#   'ስንመግብ',
#   'እንደኖርን',
#   'ነው',
#   'የምረዳውበርታ',
#   'አንቀህ',
#   'ያዝልኝብችል',
#   'እኔም',
#   'አልለቃቸው'],
#  ['ግርማ',
#   'ሰይፉ',
#   'በብቸኝነት',
#   'ሲያሸንፍ',
#   'አውራምባ',
#   'ታይምስ',
#   'ላይ',
#   'አንተ',
#   'በብቸኝነት',
#   'እንዴት',
#   'አሸነፍክ',
#   'ሲባል',
#   'እኔ',
#   'የተጠቀምኩት',
#   'ስትራቴጂ',
#   'ለየት',
#   'ይላል',
#   'ስቀሰቅስ',
#   'ብቸኛው',
#   'ሀቀኛ',
#   'ተቃዋሚ',
#   'መድረክ',
#   'ብቻ',
#   'ነው',
#   'ወይ',
#   'መድረክን',
#   'አልያም',
#   'ኢህአዴግን',
#   'ምረጡ',
#   'በማለት',
#   'ነው',
#   'ሲል',
#   'ገልጿል',
#   'መድረክ',
#   'ምን',
#   'አይነት',
#   'ድርጅት',
#   'እንደሆነና',
#   'እነ',
#   'አቶ',
#   'ግርማም',
#   'ምን',
#   'ብለው',
#   'ሲሰድቡት',
#   'እንደነበር',
#   'ይታወሳል'],
#  ['ይህ',
#   'ሰው',
#   'አይፈርድበትም',
#   'ደሞዝ',
#   'የሚከፈላቸው',
#   'ስራ',
#   'ሳየሰሩ',
#   'አንዱ',
#   'ይህ',
#   'ነበር',
#   'ህሊናውን',
#   'የሺጠ',
#   'ሰው',
#   'ብለህው',
#   'ጌቾ',
#   'ወትሮም',
#   'ለሆዱ',
#   'ያደር',
#   'አሁንም',
#   'በሳንቲም',
#   'ተሽጦ',
#   'ነው',
#   'ሰሞኑን',
#   'በአማራው',
#   'ህዝብ',
#   'ዘመቻ',
#   'የጀመረው',
#   'ለዛ',
#   'ነው',
#   'ከበቴድሮስ',
#   'አድህኖ',
#   'ጋር',
#   'ምን',
#   'ሴሰራ',
#   'እንደነበር',
#   'ይታወቃል',
#   'ስራ',
#   'ነው'],
#  ['እንዲህ',
#   'የወረደ',
#   'መሆኑን',
#   'አላውቅም',
#   'ነበርሰዎች',
#   'ስለአማራ',
#   'ሲፅፉስ',
#   'ለምንድን',
#   'ነው',
#   'እንዲህ',
#   'ከገንዘብ',
#   'ጋር',
#   'የሚያገናኙት',
#   'ምን',
#   'አይነት',
#   'በሽታ',
#   'ይሆን',
#   'ከቶ'],
#  ['ይገርማል',
#   'እኔ',
#   'ደሞ',
#   'ለኢትዮጲያ',
#   'ህዝብ',
#   'ሁሉ',
#   'የሚቆረቆር',
#   'ይመስለኝ',
#   'ነበር',
#   'ያዉ',
#   'የዜግነት',
#   'ፖለቲካ',
#   'አራማጅ',
#   'ስለሆነ',
#   'የምር',
#   'አክባሪው',
#   'ነበርኳዬዬ',
#   'ይቺ',
#   'የአማራ',
#   'ብሄርተኝነት',
#   'እንዴት',
#   'ፍትሁን',
#   'መድሀኒት',
#   'ነች',
#   'ስንቱን',
#   'ባዶ',
#   'አስቀረችው'],
#  ['በእርግጠኝነት', 'ታመዎል', 'ክቡርነትዎወይ', 'ሶስት', 'ሰባት', 'አሊያም', 'አማኑኤል', 'ቢታዩ'],
#  ['በቀደመው',
#   'ፖስት',
#   'ላይ',
#   'አድርጎህ',
#   'ይሸልላል',
#   'ያልኩትን',
#   'ወደ',
#   'ላቀ',
#   'ደረጃ',
#   'አሳድጎ',
#   'ተሳድቦና',
#   'በህፃናት',
#   'ተሳልቆ',
#   'አደረገው',
#   'ሀሳብየለሽ',
#   'ድንዙዝ',
#   'ስለሆነ',
#   'አንተ',
#   'ተገላገልክ',
#   'ፊትህን',
#   'ወደ',
#   'ስራህ'],
#  ['የማን', 'ነው', 'ደደብ', 'የቆሎ', 'ተማሪዎች', 'ላይ', 'የሚያላግጥ', 'ድንጋይ', 'ራስ'],
#  ['ሰው',
#   'መሳይ',
#   'ደግሞ',
#   'የሚገርመው',
#   'በኢሳት',
#   'እየቀረበ',
#   'የሚተረተረው',
#   'ላገር',
#   'የሚያስብ',
#   'ይመስላልአማራ',
#   'ላይ',
#   'ሁሉም',
#   'ምላሱ',
#   'እረጂም',
#   'ነው',
#   'በተራ',
#   'ሊቀጠቅጡን',
#   'ነው',
#   'የሚፈልጉት',
#   'የሚያስፈልገው',
#   'ከነዚህ',
#   'መማር',
#   'ያለብን',
#   'ይመስለኛልባንድ',
#   'አብረን',
#   'ልዩነት',
#   'እንኳን',
#   'ቢኖር',
#   'ተቻችለን',
#   'የጀመርነውን',
#   'ለመጨረስ',
#   'አስፈላጊውን',
#   'ሁሉ',
#   'ማድረግ',
#   'አለብንእንደዚህ',
#   'አይነቱ',
#   'ነው',
#   'እንግድህ',
#   'ለህዝብ',
#   'እኩልነት',
#   'ሊሰራ',
#   'ፓርላማ',
#   'አምስት',
#   'አመት',
#   'የተቀመጠው',
#   'ማፈሪያ',
#   'ነህጌችና',
#   'አንተ',
#   'አትመጣጠኑም',
#   'ሌት',
#   'ተቀን',
#   'ለህዝብ',
#   'የሚሰራ',
#   'መሆኑን',
#   'አስመስክሯልአንተ',
#   'ግን',
#   'ይኸንን',
#   'መለጠፍህ',
#   'እራሱ',
#   'የወረድክ',
#   'እንደሆነ',
#   'አንዱ',
#   'ማሳያ',
#   'ነውደግሞም',
#   'ቸግሯቸው',
#   'እንዳይመስልህ',
#   'ለመማር',
#   'ብለው',
#   'እንጂ',
#   'ከነዚህ',
#   'ነው',
#   'ነጩ',
#   'ጤፍማሩቅቤውሰሊጡ',
#   'የሚገኘው',
#   'ስለዚህ',
#   'ያንተን',
#   'ደካማነትህን',
#   'ነው',
#   'የሚገልፀው',
#   'እንጂ',
#   'ያዋረድኩኝ',
#   'እንዳይመስልህ'],
#  ['ውሸት', 'አንተ', 'ውሸታም', 'ነህ', 'እውቀትህን', 'ለረከሰ', 'አስተሳሰብ', 'ተጠቀምክ'],
#  ['ምክንያቱም',
#   'ከአግ',
#   'ጋር',
#   'ተጣላህ',
#   'ሳይሆን',
#   'ከ',
#   'እውቀት',
#   'በታች',
#   'ተጋጨህየሀሳብ',
#   'ብዝሀነትን',
#   'ለመቀበል',
#   'የሚያስችል',
#   'እውቀት',
#   'አጣህ',
#   'ይህን',
#   'እውቀት',
#   'ያለ',
#   'በሙሉ',
#   'ከእውቀት',
#   'ራቀአንተ',
#   'የሀሳብ',
#   'ሳይሆን',
#   'የቢሄር',
#   'መሪ',
#   'ነህ'],
#  ['ለካ',
#   'የማንንም',
#   'ቅሌታም',
#   'ነዉ',
#   'የተከበሩ',
#   'ስንል',
#   'የከረምነዉእኔ',
#   'እምለዉ',
#   'አማራን',
#   'ሳንሳደብየሱን',
#   'ጉዳይ',
#   'ሳንተዉ',
#   'ስለህብረብሄራዊነት',
#   'ማዉራት',
#   'አይቻልም',
#   'እንዴአማራስ',
#   'የህብረብሄራዊነቱ',
#   'አንድነቱ',
#   'አንድ',
#   'አካል',
#   'አይደለምን'],
#  ['ግርማ',
#   'ከዚህም',
#   'በላይ',
#   'እጅግ',
#   'የወረደ',
#   'ሰው',
#   'ነው',
#   'ስለርሱ',
#   'በመነጋገር',
#   'እውቅና',
#   'አትስጡት',
#   'ትኩረት',
#   'የሚያሻው',
#   'ብዙ',
#   'አንገብጋቢ',
#   'ጉዳይ',
#   'አለን',
#   'በጮኽ',
#   'ውሻ',
#   'ላይ',
#   'ሁሉ',
#   'ጠጠር',
#   'ለመወርወር',
#   'መቆም',
#   'ፋይዳው',
#   'ጊዜን',
#   'ማባከን',
#   'ብቻ',
#   'ነው'],
#  ['ግርማ', 'እኮ', 'ከጌታቸው', 'አስፋ', 'ጋር', 'ይሰራ', 'ነበር'],
#  ['ሰወች', 'አጀንዳ', 'ሲጨርሱ', 'ስለሰወች', 'በማውራት', 'ይደክማሉ', 'ተወው'],
#  ['ግርማ',
#   'ሰይፉ',
#   'ሲጀመር',
#   'የሰው',
#   'ተፈጥሮ',
#   'የሌለውና',
#   'አቋም',
#   'የለሽ',
#   'በጭባጫ',
#   'የመንደር',
#   'ውሻ',
#   'ነው',
#   'እኔ',
#   'ግርም',
#   'እሚለኝ',
#   'እንዴት',
#   'ይህ',
#   'ሰው',
#   'የፓርላማ',
#   'አባል',
#   'እንደሆነነው',
#   'ወራዳ',
#   'ብየዋለሁ'],
#  ['ጌቾ',
#   'ከባድ',
#   'ሚዛን',
#   'ከማንም',
#   'እንከፍ',
#   'ጋር',
#   'አትወዳድርምይህ',
#   'ሰው',
#   'እንደዚህ',
#   'ይጠላናል',
#   'ብየ',
#   'አስቤ',
#   'አላውቅም',
#   'ነበርድልብ',
#   'መሀይም',
#   'ነው',
#   'ለካእኔ',
#   'ለእሱ',
#   'አዘንኩለት'],
#  ['አረፍከው',
#   'ሁሌ',
#   'ከሚጨቃጨቅህ',
#   'እንዲያውም',
#   'አንተ',
#   'ነበር',
#   'ብሎክ',
#   'ማድረግ',
#   'ያለብህ',
#   'በጊዜ',
#   'መሰናበቱ',
#   'ጥሩ',
#   'ነው'],
#  ['ሰውየው',
#   'አሁን',
#   'ኢሳት',
#   'ክ',
#   'በታች',
#   'ስላወረደው',
#   'ጌቾ',
#   'አንተን',
#   'አይመጥንህምና',
#   'አንተም',
#   'ሰጠውና',
#   'ሸኘው'],
#  ['ጌች',
#   'የቪድዮን',
#   'ከአንተ',
#   'ወስጄ',
#   'ሊንክ',
#   'ሌኬለት',
#   'በጣም',
#   'ነውየተናደደብኝ',
#   'ይሄ',
#   'ቆሻሻ',
#   'አማራ',
#   'ማንነቱን',
#   'አይስትም',
#   'እሱ',
#   'ከተሜ',
#   'ነኝ',
#   'ለማለት',
#   'ከሆነ',
#   'ገበሬው',
#   'ባመረት',
#   'እህል',
#   'ነው',
#   'የጎጃምን',
#   'ነጭ',
#   'ጤፈሸ',
#   'ሺንፊላው',
#   'እስኪሞላ',
#   'መብላቱ',
#   'ነው',
#   'ወለታ',
#   'የማያውቅ',
#   'እኛ',
#   'የአረሶአደር',
#   'ልጆች',
#   'መሆናችንን',
#   'አንክደውም',
#   'የመሀል',
#   'መርካቶልጂ',
#   'መሆኑን',
#   'ሊነግረን',
#   'ካልፈለገ'],
#  ['ጌች',
#   'እንግዲህ',
#   'ህወሀት',
#   'እየከፈለ',
#   'የሚያሰራቸው',
#   'ሰዎች',
#   'ከፋያቸው',
#   'ስለሄደ',
#   'ቦዘኔ',
#   'እየሆኑ',
#   'ነው',
#   'ስለዚህ',
#   'ከተሳዳቢነት',
#   'አያልፉም',
#   'ንቀህ',
#   'ካልተውካቸው',
#   'ስራ',
#   'ያስፈቱሀል'],
#  ['ሁሉም',
#   'የአንድነት',
#   'ፓለቲካ',
#   'እራማጅ',
#   'የሚመስሉ',
#   'ብሎገሮች',
#   'ግርማ',
#   'ሰይፋ',
#   'አቤ',
#   'ቶክቻ',
#   'ስዩም',
#   'ተሾመ',
#   'በቅርቡ',
#   'ኦነግነታቸውን',
#   'እያወጁ',
#   'በኦነግ',
#   'የፓለቲካ',
#   'ፓርቲወች',
#   'ውስጥ',
#   'በቅርብ',
#   'እናያቸዋለን',
#   'ብዙ',
#   'ግዜ',
#   'ብዙ',
#   'የዋህ',
#   'አማሮች',
#   'እትሞኙ',
#   'ግርማ',
#   'ሰይፋ',
#   'እሮሞ',
#   'ፈርስትን',
#   'አልቃወምም',
#   'ያለ',
#   'አማራ',
#   'ብሄርተኛች',
#   'ላይ',
#   'ደሙ',
#   'ይፈላክ',
#   'አማራ',
#   'ለህዝብ',
#   'ህዝብህን',
#   'ብቻ',
#   'ይዘህ',
#   'ከራስክን',
#   'ፓለቲካ',
#   'ስራ',
#   'እንደምንም',
#   'ይህ',
#   'ያንደነት',
#   'ፓለቲካ',
#   'የሚባል',
#   'ነገር',
#   'በተሎ',
#   'ተላቀቅ',
#   'አብን',
#   'ቤተ',
#   'አማራ',
#   'የፈልገውን',
#   'የአማራ',
#   'ፓርቲ',
#   'ብቻ',
#   'ተቀለቀል',
#   'ሀቅ',
#   'ነገር',
#   'ይህች',
#   'እትዮጵያ',
#   'ምድር',
#   'ላይ',
#   'ጭዋታው',
#   'ከእንግዲህ',
#   'ብብሄር',
#   'ፓለቲካ',
#   'ብቻ',
#   'ነው',
#   'ግንቦት',
#   'ሰማያውይ',
#   'መኢአድ',
#   'ህብረት',
#   'የሚባሉት',
#   'ፓርቲወች',
#   'ታሪካውይ',
#   'ስራቸውን',
#   'ጭፕርሰዋክ',
#   'ለሚቀጥለው',
#   'ምርጫ',
#   'አንድም',
#   'ህብረ',
#   'ብሄራውይ',
#   'ፓርቲ',
#   'ለፓርላማ',
#   'ቢወዳደር',
#   'አንድም',
#   'መቀመጫ',
#   'እያገኝም',
#   'በሁለቱ',
#   'ትልልቅ',
#   'ህዝቦች',
#   'አማራና',
#   'ኦሮሞ',
#   'በሚዋቀር',
#   'አዲስ',
#   'መንግስት',
#   'ይህች',
#   'ሀገር',
#   'ትመራለች',
#   'ሀቁ',
#   'ይህ',
#   'ብቻ',
#   'ነው',
#   'የኦነጎች',
#   'የመገንጠል',
#   'ጥያቄ',
#   'ላለመገንጥል',
#   'ፈልገው',
#   'ሳይሆን',
#   'ያለው',
#   'ሁኔታ',
#   'እያስኬዳቸውም',
#   'ኦነጎች',
#   'አጥብቀው',
#   'እትዮጵያ',
#   'ብሄርተኛ',
#   'ሀይሎችን',
#   'የሚጠሉበት',
#   'ምክንያት',
#   'የአማራ',
#   'ህዝብ',
#   'በእትዮጵያ',
#   'ብሄርተኛች',
#   'በኩል',
#   'ድምፅን',
#   'ሰጥቶ',
#   'በምርጫ',
#   'ያሼንፋል',
#   'ብለው',
#   'ያስባሉ',
#   'ለዝህም',
#   'ይመስላል',
#   'ገና',
#   'በጥዋቱ',
#   'በሜንጫ',
#   'የታጀበ',
#   'እግሬሲብ',
#   'የምርጫ',
#   'ቅስቀሳ',
#   'በግንቦት',
#   'ላይ',
#   'የጀመሩት',
#   'ግንቦት',
#   'በዝህ',
#   'ደንግጦ',
#   'የአዲስ',
#   'አበባ',
#   'ልጆችን',
#   'አሳስሮና',
#   'አስግዞ',
#   'ፈርቶ',
#   'ፀጥ',
#   'ብሎ',
#   'ተቀምጣል',
#   'መግለጫ',
#   'እንካን',
#   'ለመስጥት',
#   'አልደፈረም',
#   'መላው',
#   'አማራ',
#   'ይህ',
#   'ያንድነቱ',
#   'ሀይል',
#   'ፓለቲካ',
#   'አማራን',
#   'ለብሄርተኛ',
#   'ሀይሎች',
#   'ጭዳ',
#   'አድርጎ',
#   'እሱ',
#   'ራሱ',
#   'ስልጣን',
#   'ላይ',
#   'የሚወጣ',
#   'የሚመስለው',
#   'አብዛኛው',
#   'የ',
#   'ቅሪት',
#   'የሆነ',
#   'የዞረበት',
#   'ፓለቲከኛ',
#   'ነው',
#   'መጭው',
#   'የዝህች',
#   'ሀገር',
#   'እጣፈንታ',
#   'ከእንግዲህ',
#   'በግልፅ',
#   'በግንባር',
#   'መላው',
#   'አማራ',
#   'ብብሄሩ',
#   'ልክ',
#   'እንደእሮሞው',
#   'ትግሬው',
#   'ብብሀልሩ',
#   'አንድ',
#   'ሁኖ',
#   'ተድራጅቶ',
#   'የእትዮጵያን',
#   'ፓለቲካ',
#   'ችግር',
#   'አምጡ',
#   'በአንድ',
#   'ላይ',
#   'እንፍታው',
#   'ሲል',
#   'ብቻ',
#   'ነው'],
#  ['ግርማ',
#   'የተባለን',
#   'ሰውዬ',
#   'ስሙ',
#   'መሬት',
#   'ላይ',
#   'ሲጎተት',
#   'እያየሁት',
#   'አልፌው',
#   'ነበር',
#   'ዛሬ',
#   'ደግሞ',
#   'ጭራሽ',
#   'በዝቶ',
#   'አይሁት',
#   'ጌች',
#   'አንተን',
#   'በሰማይ',
#   'ጀት',
#   'በምድር',
#   'ታንክ',
#   'ተጠምዶ',
#   'እስክብሪቶ',
#   'ይዘህ',
#   'ጋንቤላ',
#   'አርማጭሆ',
#   'በለሳ',
#   'ወልቃይት',
#   'ጠገዴ',
#   'ዋግኸምራ',
#   'ራያ',
#   'ቆቦ',
#   'ኦሮምያ',
#   'ስትሄድ',
#   'ከፊትህ',
#   'ሞት',
#   'እንዳለ',
#   'አላወቀም',
#   'ወይ'],
#  ['እንደዚህ',
#   'ሳይሆኑ',
#   'መሞት',
#   'ምንኛ',
#   'ደስ',
#   'ይላልይህ',
#   'ነው',
#   'እንግዲህ',
#   'ህዝብ',
#   'ወክሎ',
#   'ለ',
#   'አመት',
#   'የፓርላማ',
#   'አባል',
#   'የነበረ'],
#  ['ከግርማ',
#   'ሰይፉ',
#   'ጋር',
#   'ለመከራከር',
#   'የአማራን',
#   'ህዝብ',
#   'ተገን',
#   'እያረክ',
#   'ነው',
#   'ራስህን',
#   'ችለህ',
#   'ተከራከር',
#   'ሸቀጥህን',
#   'የምታራግፍበት',
#   'ቦታ',
#   'ራስህ',
#   'ፈልግ',
#   'እንጂ',
#   'አንድ',
#   'ማህበረሰብ',
#   'ላይ',
#   'አትጫን',
#   'አንተ',
#   'አንተ',
#   'ብቻ',
#   'ነህአንተ',
#   'ከተነካህ',
#   'አንተ',
#   'ብቻ',
#   'ነህ',
#   'የተነካኸው',
#   'እንጂ',
#   'አንተ',
#   'የበቀልክበት',
#   'ብሄር',
#   'ሊሆን',
#   'አይችልም',
#   'እዛው',
#   'እንደፍጥርጥርህ'],
#  ['እሱ',
#   'እኮ',
#   'ባንድ',
#   'በኩል',
#   'ተቃዋሚ',
#   'ነኝ',
#   'እያለ',
#   'በሌላ',
#   'በኩል',
#   'በወያኔ',
#   'ቤት',
#   'ሲርመጠመጥ',
#   'ነበር',
#   'የሚያመሸው',
#   'ፐብሊክ',
#   'ዲፕሎማሲ',
#   'አባል',
#   'ምናምን',
#   'እያለ',
#   'ከነቴድሮስ',
#   'አድሀኖም',
#   'ጋር',
#   'ሽር',
#   'ብትን',
#   'ሲል',
#   'የኖረ',
#   'አጎብዳጅ',
#   'ነው',
#   'እሱ',
#   'ሀገሪቷ',
#   'ምን',
#   'ያህል',
#   'ሰው',
#   'ያጣች',
#   'መሆኗ',
#   'ማሳያ',
#   'ነው',
#   'ደህና',
#   'ሰው',
#   'ቢኖር',
#   'እንኳን',
#   'ህዝብ',
#   'ሊወክል',
#   'ከምንም',
#   'ማይገባ',
#   'ሰው',
#   'ነበር'],
#  ['አቶ',
#   'ግርማም',
#   'ሆንክ',
#   'አቶ',
#   'ጌታቸው',
#   'ለሀገራችን',
#   'ለውጥ',
#   'በየግላችሁ',
#   'የአቅማችሁን',
#   'ሰርታችሆል',
#   'ነገር',
#   'ግን',
#   'ሀገራችንን',
#   'የያዛት',
#   'የመጠላለፍና',
#   'የእልህ',
#   'ፖለቲካ',
#   'አባዜ',
#   'ይዞችሁ',
#   'ይሂው',
#   'ያባላችሆል'],
#  ['አማራን',
#   'እየስጠቀ',
#   'እንደሆንክ',
#   'መወቅ',
#   'አለብህ',
#   'እንደ',
#   'አንተ',
#   'አይነቱ',
#   'አሸበሪ',
#   'ሰዎች',
#   'በጨረሽ',
#   'አማራን',
#   'መወከል',
#   'የለበቹም',
#   'መንግስት',
#   'ለምን',
#   'እነደምፈተብን',
#   'መጠየቅ',
#   'አለብን'],
#  ['ደና',
#   'ሰው',
#   'ይመስለኝ',
#   'ነበር',
#   'ስለ',
#   'ፓይለቱም',
#   'የተናገረው',
#   'ያው',
#   'ላለው',
#   'አንፃራዊ',
#   'መረጋጋት',
#   'ወግኖ',
#   'ነው',
#   'በማለት',
#   'ለማለፍ',
#   'ሞከርሁ',
#   'እንዲህ',
#   'ድብቅ',
#   'ሴራ',
#   'እና',
#   'እንዳለው',
#   'ግን',
#   'ተወዛግቤ',
#   'ነበር'],
#  ['ግርማ',
#   'ሰይፉ',
#   'የደህንነት',
#   'አባል',
#   'የነበረ',
#   'ነዉ',
#   'በ',
#   'በተደረገዉ',
#   'ምርጫ',
#   'ብቸኛ',
#   'የፓርላማ',
#   'አባል',
#   'ነበር',
#   'ጌታቸዉ',
#   'አሰፉ',
#   'ሲጠየቅ',
#   'አባላችን',
#   'ስለሆነነዉ',
#   'ያስመረጥነዉ',
#   'ብላል',
#   'ካሁን',
#   'በሀላ',
#   'በአማራ',
#   'ህዝብ',
#   'ደም',
#   'መቀለድ',
#   'አይቻልም',
#   'መነገጃም',
#   'አይደለም',
#   'በላካት',
#   'ፎቶ',
#   'በአማራ',
#   'ህዝብ',
#   'ላይ',
#   'እንደቀለድክ',
#   'ከህወት',
#   'ወይም',
#   'ከተወልደ',
#   'ለይተን',
#   'አናይህም',
#   'አንተ',
#   'ሆድ',
#   'አደር',
#   'ባንዳ'],
#  ['ግርማ',
#   'የሚባል',
#   'ጭንጋፍ',
#   'ደንቆሮ',
#   'ትግሬ',
#   'እንደሆነ',
#   'እናውቃለንሰሞኑነ',
#   'ክፉኛ',
#   'አቅለብልቦታል',
#   'እንደዚህ',
#   'ያንቀዠቀዠው',
#   'ወይከኢትዮጵያ',
#   'አለያም',
#   'ከአለም',
#   'እስከወዲያኛው',
#   'ሊለያይ',
#   'የፈለገ',
#   'ይመስላል'],
#  ['እሱ',
#   'እኮ',
#   'በ',
#   'አም',
#   'የተገኘ',
#   'ብቸኛ',
#   'ፍርፋሪ',
#   'ለቃሚ',
#   'ነው',
#   'የሚሰማው',
#   'ቢያገኝ',
#   'ገና',
#   'ብዙ',
#   'ይዘላብዳል',
#   'አይ',
#   'የሳምሶናይት',
#   'ፓርቲ',
#   'ነገር'],
#  ['ይህ',
#   'እንዝዝ',
#   'ፊት',
#   'ምን',
#   'ያህል',
#   'የዘቀጠ',
#   'እንደሆነ',
#   'ያሳያል',
#   'እሱን',
#   'ብሎ',
#   'የፓርላማ',
#   'አባል',
#   'ይህን',
#   'የወደቀ',
#   'እና',
#   'ስዋዊ',
#   'ባህሪ',
#   'ሳይቀይር',
#   'ከስው',
#   'ጋር',
#   'ይኖራል',
#   'ዝቃጭ'],
#  ['ደነዝ'],
#  ['ጌች',
#   'አንተ',
#   'ከፍታ',
#   'ላይ',
#   'ሆነህ',
#   'እንደ',
#   'ንስር',
#   'ቁልቁል',
#   'የምታየውን',
#   'ጉማሬ',
#   'ጋር',
#   'መልስ',
#   'ስትሰጠው',
#   'የተረሳውን',
#   'አለሁ',
#   'እንዲል',
#   'ነውና',
#   'እባክህ',
#   'ከማይመጥንህ',
#   'ቆሞ',
#   'ቀር',
#   'ጋር',
#   'ያለውን',
#   'ትተህ',
#   'በየደቂቃው',
#   'በምትሰጠን',
#   'መረጃ',
#   'እኛን',
#   'አበርታ'],
#  ['ተወው',
#   'ቦታ',
#   'አትስጠዉ',
#   'መለስ',
#   'ተስፋ',
#   'አድርጎለት',
#   'የነበረውን',
#   'የተላላኪነት',
#   'ሚና',
#   'የአሁኖቹ',
#   'ከነ',
#   'አየለ',
#   'ጫሚሶም',
#   'አሳንሰውበት',
#   'ፊት',
#   'ስለነሱት',
#   'የእነሱን',
#   'ንዴት',
#   'በሚጠላው',
#   'አማራ',
#   'ላይ',
#   'መወጣቱ',
#   'ነው',
#   'ከንቱ',
#   'እና',
#   'በክት',
#   'አውደልዳይ',
#   'ብቻ',
#   'ለመሆኑ',
#   'ሆላንድ',
#   'ካር',
#   'ጋር',
#   'የሰራውን',
#   'ሸፍጥ',
#   'ማስታወስ',
#   'በቂ',
#   'ነው',
#   'ጀንበር',
#   'እስክትወጣ',
#   'እድሜን',
#   'እመኝለታለሁ',
#   'እኔ',
#   'ማዳናችንን',
#   'ሳያይ',
#   'እንዳይሞት'],
#  ['ይኸ',
#   'ዘመን',
#   'መልካም',
#   'አጋጣሚ',
#   'አሰተምሮናል',
#   'ወዳጅ',
#   'ጠላታችንን',
#   'ለይተንበታል',
#   'ለአገራችን',
#   'መልካም',
#   'የዴሞክራሲ',
#   'ዘመን',
#   'ከመጣ',
#   'የማይዛባ',
#   'አቋም',
#   'ያላቸው',
#   'ግለሰብ',
#   'ፓለቲከኞች',
#   'ከአንክርዳዱ',
#   'እንዲለዩ',
#   'ሆኖል',
#   'እናም',
#   'ሆድ',
#   'አደር',
#   'ከርሳሞች',
#   'ጠብቁ',
#   'የምትነቀሉበት',
#   'ጊዜው',
#   'ደርሶአል'],
#  ['አማርኛ', 'ራሱ', 'በትክክል', 'መፃፍ', 'አይችልም', 'ማለት', 'ነው'],
#  ['ቀና', 'ስንል', 'ወዳጅ', 'እና', 'ጠላታችን', 'ይታዩን', 'ጀመር'],
#  ['ይህ', 'አድር', 'ባይ', 'አርፎ', 'ይቀመጥ'],
#  ['ግርማ',
#   'ጠጅና',
#   'ቁርጥ',
#   'ለገዛለት',
#   'ሁሉ',
#   'ጭራዉን',
#   'የሚቆላ',
#   'የዉስኪ',
#   'ጠርሙስ',
#   'ሲጨብጥ',
#   'ወደ',
#   'አልጋ',
#   'የሚጣድፍ',
#   'ዥልጥ',
#   'ነዉ'],
#  ['ጌች',
#   'በርታ',
#   'ወንድማለም',
#   'አንተ',
#   'ሚዛናዊ',
#   'እና',
#   'ውሸት',
#   'የሌለብህ',
#   'ምርጥ',
#   'ጋዜጠኛ',
#   'ነህ'],
#  ['በቁምህ', 'ሞተሀል', 'ለካ'],
#  ['ይሄን',
#   'ሁሉ',
#   'የፊደል',
#   'ግድፈት',
#   'ሳይ',
#   'በፍርሀት',
#   'እጁ',
#   'እየተንቀጠቀጠ',
#   'እንደፃፈው',
#   'ብጠረጥርስ'],
#  ['አንድ',
#   'አንዴ',
#   'የኢትዮጵያን',
#   'ህዝብ',
#   'አምላክ',
#   'ከወያኔ',
#   'ሳይሆን',
#   'ተቃዋሚ',
#   'መስለው',
#   'ከተደበቁ',
#   'ተኩላዎች',
#   'ነው',
#   'ሲጠብቀው',
#   'የኖረው'],
#  ['ጌች', 'ለቀቅ', 'እሺሺ'],
#  ['ግርማ', 'ሰይፈን', 'ቦታ', 'ሰጣችሁትችግሩ', 'እሄ', 'ነው'],
#  ['በጣም', 'ሲበዛ', 'ቅሌታም', 'ሰውነው', 'ግርማ', 'የሚባለው', 'ዝጆሮ'],
#  ['ወናፍ',
#   'ጋ',
#   'በቅርፅም',
#   'በግርም',
#   'ለመሆን',
#   'መፍጠን',
#   'ትርፉ',
#   'እንደሰው',
#   'አለመቆጠር',
#   'ነው',
#   'ይህን',
#   'ደግሞ',
#   'ሰሚ',
#   'ያጣ',
#   'አንጎራጓሪነትን',
#   'ያገኘዋል'],
#  ['ግርማ', 'ሰይፉ', 'ሆዳም', 'የወያኔ', 'ተላላኪ', 'ነው', 'የህዝብ', 'ልጅ', 'ነህኑርልን', 'በርታልን'],
#  ['ግርማ', 'ሰይፉ', 'ሆዳም', 'የወያኔ', 'ተላላኪ', 'ነው', 'የህዝብ', 'ልጅ', 'ነህኑርልን', 'በርታልን'],
#  ['አይ', 'ሞራል', 'እንደው', 'አማራ', 'ላይ', 'ብቻ', 'ቀረሽ'],
#  ['ምን', 'ሆነህ', 'ነው', 'ግን', 'እንዲህ', 'አይነት', 'ስድብአረ', 'የተከበሩ', 'አይደሉም', 'እንዴ'],
#  ['የባህር',
#   'ዳር',
#   'ከነማ',
#   'ደጋፊዎች',
#   'በመኪና',
#   'አደጋ',
#   'ህይወታቸው',
#   'ያለፈ',
#   'የፋሲል',
#   'ከነማ',
#   'ደጋፊዎችን',
#   'በሻማ',
#   'ማብራት',
#   'እያሰቧቸው',
#   'ነው'],
#  ['ማንም',
#   'ይሁን',
#   'ማንም',
#   'በድንገት',
#   'በዚህ',
#   'ሁኔታ',
#   'መሞት',
#   'ያማል',
#   'ነብስ',
#   'ይማር',
#   'እትዮጵያዊያን',
#   'ወገኖቸ'],
#  ['አብን',
#   'ስለ',
#   'ድሬ',
#   'ከየትኛውም',
#   'ተፎካካሪ',
#   'ፓርቲ',
#   'ቀድሞ',
#   'የሀዘን',
#   'መግለጫ',
#   'አወጣ',
#   'ይህው',
#   'ደግሞ',
#   'ጎጠኝነትና',
#   'ዘረኝነት',
#   'የማይነካካቸው',
#   'የጣናው',
#   'ሞገዶች',
#   'ለህዝባቸው',
#   'ቀድመው',
#   'የሻማ',
#   'ማብራት',
#   'ስራ',
#   'ሰሩ',
#   'ለዚህም',
#   'እኮ',
#   'ነው',
#   'አማራንት',
#   'የሰውነት',
#   'ውሀ',
#   'ልክ',
#   'ነው',
#   'የምንለው'],
#  ['ይኸ',
#   'አያሌው',
#   'ወንበር',
#   'የሚባልና',
#   'ጌታቸው',
#   'ሺፈራው',
#   'ድሮም',
#   'ዘንድሮም',
#   'ላንድ',
#   'ድርጅት',
#   'ይሆን',
#   'የሚሰሩት',
#   'ሀሳባቸው',
#   'ብቻ',
#   'አደለም',
#   'የሚጠቀሟቸው',
#   'ፊደሎች',
#   'በካርቦን',
#   'የተገለበጡ',
#   'ይመስላሉ',
#   'አይ',
#   'ወያኔ',
#   'አስመስሎ',
#   'መፍጠር',
#   'እንዴት',
#   'ትችላለች'],
#  ['በጣም', 'ያሳዝናሉ', 'ለቤተሰብ', 'መፅናናትን', 'ነብስ', 'ይማር'],
#  ['ነፍስ', 'ይማር'],
#  ['ከርእሰ',
#   'መስተዳደር',
#   'ቢሮ',
#   'ታፍኖ',
#   'ስራ',
#   'አመራር',
#   'ቢሮ',
#   'ተወስዶ',
#   'የነበረውና',
#   'ከግድያ',
#   'የተረፈው',
#   'የዶር',
#   'አምባቸው',
#   'ሶስተኛ',
#   'ሹፌር'],
#  ['አይ',
#   'የደራ',
#   'ሰው',
#   'ምግባሩም',
#   'ከወፍ',
#   'አርግፍ',
#   'መጦ',
#   'ነው',
#   'ወገኑን',
#   'ሲያስጨርስ',
#   'የኖረው'],
#  ['ወንድሜ',
#   'እረ',
#   'ባክህ',
#   'እሄ',
#   'እኮ',
#   'አይጠቅምም',
#   'አሁን',
#   'ለምስኪኑ',
#   'ህዝብ',
#   'ሚጠቅም',
#   'ሀሳብ',
#   'ፈልጉ',
#   'ሲቀጥል',
#   'እሄን',
#   'ሚከፋፍል',
#   'ሀሳብ',
#   'እየለቃቀሙ',
#   'እከሌን',
#   'እከሌ',
#   'ገደለው',
#   'እያሉ',
#   'ሚሰሩልን',
#   'ብዙ',
#   'ጠላቶች',
#   'አሉ',
#   'ደግነቱ',
#   'የአማራ',
#   'ህዝብ',
#   'በማንም',
#   'ገንቦ',
#   'ሆድ',
#   'ሚከፋፈል',
#   'ተልካሻ',
#   'ህዝብ',
#   'አይደለም'],
#  ['ስትከፍለዉህ',
#   'ይሆን',
#   'እዲህ',
#   'የምቀባጥረዉ',
#   'አያለው',
#   'ሙሉቀን',
#   'አሉ',
#   'ሌላም',
#   'አባቴን',
#   'ጀነራል',
#   'አሳምነው',
#   'ያስገደላችሁት',
#   'እናተናችሁ',
#   'የግዜ',
#   'ጉዳይ',
#   'ነው',
#   'ቀናችሁን',
#   'ጠብቁ'],
#  ['የአለም', 'አስራደ', 'ልጅ', 'ስሚዝ', 'ወንድሜ', 'ነገሩ', 'ብዙ', 'ነውተወኝማይልቅስ', 'መርምር'],
#  ['አንዱ',
#   'መንግስት',
#   'በቡልኬት',
#   'የሚሰራላቸው',
#   'ከሶማሌ',
#   'ለተፈናቀሉ',
#   'ኦሮሞዎች',
#   'ቦሌ',
#   'አራባሳ',
#   'የተባለ',
#   'ቦታ',
#   'የሚሰራው',
#   'ቤት',
#   'ሲሆን',
#   'ሌላኛው',
#   'ራሳቸው',
#   'የሰሩት',
#   'ቡልኬት',
#   'ቤታቸው',
#   'የፈረሰባቸው',
#   'ደግሞ',
#   'ለገጣፎ',
#   'እየፈረሰባቸው',
#   'ያሉ',
#   'ኦሮሞ',
#   'ያልሆኑ',
#   'ኢትዮጵያውያን',
#   'ቤት',
#   'ነው'],
#  ['ምናለበት', 'አስራት', 'ቶሎ', 'ብሎ', 'መደበኛ', 'ፕሮግራሙን', 'ቢጀምር'],
#  ['የተፈናቀሉት',
#   'ኦሮሞ',
#   'ቤት',
#   'ይስራል',
#   'ቤት',
#   'የሰሩ',
#   'አማራትግራይ',
#   'ጉራጌ',
#   'ስልጤ',
#   'ያፈርሳል',
#   'ግልጥ',
#   'ነው'],
#  ['የፊንፊኔን',
#   'ኦሮሞ',
#   'ከጤፍ',
#   'ማሳው',
#   'ላይ',
#   'አፈናቅላችሁ',
#   'በሚሊየን',
#   'ብር',
#   'ስትቸበችቡ',
#   'ኦሮሞ',
#   'በቀስት',
#   'ሲገደልና',
#   'ሲፈናቀል',
#   'በሚሊየን',
#   'ከሶማሊያ',
#   'ንብረቱ',
#   'ተዘርፎ',
#   'ሲባረር',
#   'ሰብአዊነት',
#   'ይቀድማል',
#   'ብላችሁ',
#   'ብትጮሁ',
#   'ሰብአዊ',
#   'አስተሳሰብ',
#   'ነበራችሁ',
#   'ይባላል'],
#  ['ዛሬ',
#   'ህገወጥ',
#   'ግንባታ',
#   'ፈረሰ',
#   'ብሎ',
#   'ሰብአዊነት',
#   'ይቅድማል',
#   'ብሎ',
#   'መቀደድ',
#   'ፋይዳ',
#   'የለውም'],
#  ['በሁሉም',
#   'ከተማ',
#   'ህገወጥ',
#   'ግንባታ',
#   'መፍረስ',
#   'ይቀጥላል',
#   'ከንቲባችን',
#   'ጀግኒትወሮ',
#   'ሀቢባ',
#   'ሲራጅ',
#   'የለገጣፎ',
#   'ከተማ',
#   'ከንቲባ',
#   'በርቺ',
#   'ከጎንሽ',
#   'ነን'],
#  ['የፌዴራል',
#   'መንግስት',
#   'በክልል',
#   'ጉዳይ',
#   'በተለይ',
#   'ህገወጥ',
#   'የመሬት',
#   'ወረራን',
#   'ፍቀዱ',
#   'ብሎ',
#   'ጣልቃ',
#   'አይገባም'],
#  ['በህግና',
#   'ስርአት',
#   'ቤት',
#   'የሰራ',
#   'አይፈርስበትም',
#   'ህገወጥ',
#   'ከሆነ',
#   'ግን',
#   'ሰውም',
#   'ይፈርሳል'],
#  ['ቤት', 'ብሄር', 'የለውም', 'ዬትኛውም', 'ብሄር', 'ህገወጥ', 'ከሆነ', 'ይፈርስበታል'],
#  ['ያኔ',
#   'አርሶ',
#   'አደሮች',
#   'ከሸገርና',
#   'ዙሪያዋ',
#   'ሲፈናቀሉ',
#   'ለልማት',
#   'ነበር',
#   'የተባሉት',
#   'እናም',
#   'አንተም',
#   'እሰይ',
#   'አርሶአደሮች',
#   'ይነሱ',
#   'ሸገርም',
#   'ትለጠጥ',
#   'ስትል',
#   'ነበር'],
#  ['የለውጡ',
#   'መነሻ',
#   'የመሬት',
#   'መቀራመትና',
#   'ያላግባብ',
#   'መዝረፍ',
#   'ነበር',
#   'እናም',
#   'በእጃዙር',
#   'ከቀጠለ',
#   'ያው',
#   'ለውጡ',
#   'ለህገወጥነት',
#   'መሆኑ',
#   'ይሆናልና',
#   'ህግ',
#   'ማስከበርን',
#   'ስትቃወም',
#   'ብሄርን',
#   'ሽፋን',
#   'አድርህ',
#   'መሆኑ',
#   'ነው'],
#  ['ወይ',
#   'ኢትዮጰዊነት',
#   'አረ',
#   'ንቃ',
#   'ንቃ',
#   'አማራው',
#   'ንቃ',
#   'አትሁ',
#   'እቃ',
#   'እቃ',
#   'የትግራይ',
#   'የበላይነት',
#   'በጉልበት',
#   'የኦሮሞ',
#   'የበላይነት',
#   'በማስመሰል',
#   'የግል',
#   'አስታየቴ',
#   'ነው',
#   'እናንተስ',
#   'ምን',
#   'ትላላችሁ'],
#  ['ኦነጋውያን',
#   'ቢረጋጉ',
#   'የተሻለ',
#   'ነው',
#   'ካልሆነ',
#   'በቅርብ',
#   'አስመራ',
#   'ወይም',
#   'ማዳጋስካር',
#   'እንዲከትሙ',
#   'ይደረጋል'],
#  ['ታድያ',
#   'ቦሌ',
#   'አራብሳ',
#   'የኦሮሚያ',
#   'ክልል',
#   'ነው',
#   'መንግስት',
#   'በክልሉ',
#   'ለሚገነባው',
#   'ግንባታ',
#   'የማንም',
#   'ፍቃድ',
#   'አያስፈልገውም',
#   'በመፍረስ',
#   'ላይ',
#   'ያለው',
#   'ህገወጥ',
#   'ወረራ',
#   'በግለሰቦች',
#   'የተከናወነ',
#   'እንጂ',
#   'በመንግስት',
#   'የተከናወነ',
#   'ግንባታ',
#   'አይደለም',
#   'ሁለቱ',
#   'ምልከታዎችህ',
#   'አራምባና',
#   'ቆቦ',
#   'ናቸው'],
#  ['ይሄ',
#   'ሁሉ',
#   'ቤት',
#   'ሲገነባ',
#   'የት',
#   'ነበሩ',
#   'ህገወጥ',
#   'ከሆነ',
#   'ማብራት',
#   'አንዴት',
#   'ገባላቸው',
#   'ግብርስ',
#   'አንዴት',
#   'ይከፍላሉ',
#   'ትልቁ',
#   'ነገር',
#   'ሰኞና',
#   'ማክሰኞ',
#   'የህፃናት',
#   'ጨዋት',
#   'የአፈራረሱ',
#   'ተብለው',
#   'ሲጠየቁ',
#   'ፋና',
#   'ቴሌቨዥን',
#   'ላይ',
#   'የመሬት',
#   'አስተዳደር',
#   'ሀላፊው',
#   'የመለሱት',
#   'መልስ',
#   'ያስቃል',
#   'ለእኛሙስሊሞችዘርኝነት',
#   'ጥብናት',
#   'ተዋት',
#   'ቅን',
#   'ልቦና',
#   'ይስጣችሁ'],
#  ['የሶስት',
#   'ቀን',
#   'አራስ',
#   'ቤቷ',
#   'ፈርሶ',
#   'ተጠፈናቅላ',
#   'ጎዳና',
#   'ላይ',
#   'ስትወድቅ',
#   'አየስውር',
#   'በቱ',
#   'ፈርሶ',
#   'ጎዳና',
#   'ላይ',
#   'ሲወረወር',
#   'ከማየት',
#   'የበለጠ',
#   'አስከፊ',
#   'ነገር',
#   'አለ',
#   'ጎበዝ',
#   'እኛ',
#   'አብይን',
#   'ደግፈናል',
#   'ስህተት',
#   'ሲሰራ',
#   'ግን',
#   'አለመውቀስ',
#   'ወይም',
#   'አለመናገር',
#   'ያስተዛዝበናል'],
#  ['በረራ', 'በረራ', 'ስትል', 'ምስኪኑን', 'ህዝቡ', 'አስበላኸው', 'ለማንኛውም'],
#  ['እዛ',
#   'ተቀምጦ',
#   'እንደ',
#   'ሽንኩርት',
#   'መሬቱን',
#   'የቸበቸበው',
#   'የኦሮሞ',
#   'ቀበሌ',
#   'ድንዙዝ',
#   'መሪ',
#   'ለፈረሰባችው',
#   'ብሩን',
#   'ይመልስ',
#   'ከአሩሲ',
#   'እና',
#   'ከወለጋ',
#   'አክራሪ',
#   'ብሄርተኛ',
#   'ሰፈርተኛ',
#   'የቀበሌ',
#   'አስተዳዳሪ',
#   'አምጥታችሁ',
#   'ለሰው',
#   'ልጅ',
#   'ያዝናሉ',
#   'ማለት',
#   'አይቻልም',
#   'የጃዋርና',
#   'መሰል',
#   'የተንኮል',
#   'ጠንሳሾች',
#   'ከድርጊታችሁ',
#   'ብትታቀቡ',
#   'ይሻላል'],
#  ['መሬት', 'ወረራን', 'ለማስቆም', 'ተጠናክሮ', 'ይቀጥላል', 'በሁሉም', 'አካባቢ'],
#  ['የተባልክ',
#   'ድፍን',
#   'ጭንቅላት',
#   'በዚህ',
#   'አስተሳሰብህ',
#   'ሰውን',
#   'ስትወርፍ',
#   'ትንሺ',
#   'አይሰቀጥጥህም',
#   'አብይን',
#   'ደገፍኩት',
#   'ማለት',
#   'እሱ',
#   'የሚመራው',
#   'አስተዳደር',
#   'ጥፋት',
#   'ሲጠፋ',
#   'እሱን',
#   'ከመተቸት',
#   'ማነው',
#   'የሚስቆመኚ',
#   'እኔ',
#   'እኮ',
#   'አብይን',
#   'የወደድኩት',
#   'በመልካም',
#   'አስተሳሰቡና',
#   'ተግባሩ',
#   'ነው',
#   'ካጠፋ',
#   'ደግሞ',
#   'የመተቼት',
#   'መብቴ',
#   'የተከበረ',
#   'ነውሰጀመር',
#   'ከጌታቸው',
#   'በላይ',
#   'ነገሩን',
#   'ፖለቲካዊ',
#   'ያደረከው',
#   'አስመሳዩ',
#   'አንተ',
#   'ነህ',
#   'ከነዚህ',
#   'ምስኪን',
#   'ኢትዮጵያኖች',
#   'መከራና',
#   'በደል',
#   'በላይ',
#   'ለአብይ',
#   'ወንበር',
#   'ጥብቅና',
#   'መቆምህ',
#   'ማንነትህን',
#   'ያሳያል',
#   'በኢትዮጵያኖች',
#   'ላይ',
#   'የሚደረሰው',
#   'ግፍና',
#   'በደል',
#   'የትኛውም',
#   'ሽፋን',
#   'ቢሰጠውም',
#   'ተቀባይነት',
#   'የለውም'],
#  ['ብዙ',
#   'መልካም',
#   'ስራ',
#   'ሰርቶ',
#   'ለአለም',
#   'ሁሉ',
#   'ያሳየ',
#   'ነው',
#   'መታገስ',
#   'ጥሩነው',
#   'ቢያጠፋም',
#   'ያስተካክላል',
#   'ባንዴ',
#   'መፈጥፈጥ',
#   'ሰዉ',
#   'ምን',
#   'ነካው',
#   'ግን'],
#  ['ምድነው',
#   'ግን',
#   'የተበተነው',
#   'አዚም',
#   'በዝብላይ',
#   'እዝቡኮ',
#   'ምንም',
#   'እደሌለ',
#   'ለሽ',
#   'አለ',
#   'ጎበዝ',
#   'በዚው',
#   'ከቀጠሉኮ',
#   'የያዳዳችን',
#   'የመኖር',
#   'ዋስትና',
#   'አደጋላይ',
#   'ነው'],
#  ['አስቀድሞ',
#   'መስጋና',
#   'ና',
#   'ጮቤ',
#   'ረገጣው',
#   'እድህ',
#   'አሁን',
#   'ለመማረር',
#   'አይደል',
#   'የነ',
#   'አብቹ',
#   'ኦነግ',
#   'ማኒፌቶ',
#   'ደግሞ',
#   'ይህ',
#   'ነው',
#   'ከወያኔ',
#   'ስረወ',
#   'መንገስት',
#   'ወደ',
#   'ኦደፓኦነግ',
#   'ስረወ',
#   'መንግስት',
#   'እንኳን',
#   'አደረሳችሁ',
#   'አማራወቸ'],
#  ['አንድ',
#   'መንግስት',
#   'በምያስተዳድረው',
#   'ክልል',
#   'ላይ',
#   'ህገወጥ',
#   'ተግባርን',
#   'ሊከላከል',
#   'ይገባልያን',
#   'ሲያደርግም',
#   'ነው',
#   'መንግስት',
#   'የሚባለውለፖለቲካ',
#   'ፍጆታ',
#   'ዘረኞች',
#   'ዘር',
#   'እየመዘዛችሁ',
#   'ኡኡ',
#   'ብትሉ',
#   'ከንቱ',
#   'ጩኽት',
#   'ነውየሚያስጠላው',
#   'ደግሞ',
#   'እንዳንተ',
#   'አይነቱ',
#   'አዛኝ',
#   'መስሎ',
#   'ድብቅ',
#   'አጀንዳውን',
#   'የሚያራግብ',
#   'ውሻ',
#   'ሲጮህ',
#   'ነው'],
#  ['ዛሬ', 'ኦዲፒ', 'ተመሳሳይ', 'ስህተት', 'ሲሰራ', 'ታሪክ', 'ራሱን', 'እንዳይደግም', 'ፈራሁ'],
#  ['ቤታቸው',
#   'ላያቸው',
#   'ላይ',
#   'ፈርሶ',
#   'ጎዳና',
#   'ላይ',
#   'የተጣሉ',
#   'እናቶችስ',
#   'ምን',
#   'እስኪሆን',
#   'ይታገሱ',
#   'መንግስት',
#   'ራሱ',
#   'አፍራሽ',
#   'መንግስት',
#   'ራሱ',
#   'ፈራጅ',
#   'ለማንስ',
#   'ይጩሁ',
#   'እነዚህ',
#   'ዜጎች',
#   'መንግስት',
#   'ወገኖቻችን',
#   'ላይ',
#   'ህገወጥ',
#   'በደል',
#   'ሲያደርስ',
#   'ለመጮህ',
#   'ዘር',
#   'ሳይሆን',
#   'ሰው',
#   'መሆን',
#   'ብቻ',
#   'በቂ',
#   'ነው',
#   'ትላንት',
#   'ወያኔ',
#   'አቆሰለን',
#   'ጠባሳው',
#   'አልሻረም'],
#  ['ኦሮሞ', 'ያልሆኑት', 'ስጀመር', 'ኦሮሚያ', 'ውስጥ', 'በህግ', 'አግባብ', 'ውጪ', 'ለምን'],
#  ['እኛ', 'ግን', 'ደስስስስ', 'ብሎናል', 'የነፍጠኛ', 'ጥጋብ', 'አስተንፍሶልናል'],
#  ['ይገርማል',
#   'ወያኔ',
#   'መቀሌ',
#   'ሆኖ',
#   'ስራው',
#   'በሚገባ',
#   'እየተዋጣ',
#   'ነው',
#   'ደር',
#   'አብይ',
#   'የእጅህ',
#   'ይስጥህ',
#   'አመስግነን',
#   'ሳነጨረስ',
#   'አማራና',
#   'ኦሮም',
#   'እጅና',
#   'ጓንት',
#   'ሁነው',
#   'ወያኔ',
#   'ወደ',
#   'መቀሌ',
#   'እንዲሸሽ',
#   'ሰርቶው',
#   'ነበር',
#   'አሁን',
#   'ግን',
#   'የነ',
#   'አባይ',
#   'ፀሀየ',
#   'ደስታ',
#   'እየሆነ',
#   'ነው',
#   'አማራው',
#   'እና',
#   'ኦሮሞው',
#   'ከተጋጩ',
#   'ወየኔ',
#   'ተመልሰው',
#   'አደስ',
#   'አበባ',
#   'የመመለስ',
#   'አላማቸው',
#   'መሳካቱ',
#   'አይቀሬ',
#   'ነው'],
#  ['ተባኖብሻል',
#   'አንዱ',
#   'ደላላ',
#   'አንተ',
#   'ነበርክ',
#   'አይደል',
#   'ቁ',
#   'አይሳካም',
#   'ገና',
#   'ምኑ',
#   'ተነካና',
#   'አሁን',
#   'የእውነት',
#   'ለሰዎቹ',
#   'አዝነነውየፖለቲካ',
#   'ነጋዴ',
#   'መሆንህን',
#   'ባወቁት'],
#  ['ከወያኔ', 'የባሱ', 'ስግብግቦች'],
#  ['እሰይይይይይይይ', 'እልልልልልልል'],
#  ['ገና', 'አናትህ', 'ውስጥ', 'ያለው', 'መጥፎ', 'አስተሳሰብ', 'ይፈርሳል'],
#  ['ሰካራም', 'ሹፌርወደ', 'ከተማ', 'እየተቃረብን', 'ነው', 'መሰለኝ'],
#  ['ቄሮ',
#   'ነኝ',
#   'የሚለው',
#   'የጀዋር',
#   'አምላኪ',
#   'ቡድን',
#   'ከሁለት',
#   'አመት',
#   'በላይ',
#   'የፈጀበትን',
#   'ትግል',
#   'አማራ',
#   'ከእንቅልፉ',
#   'ሲነቃ',
# ...
#  ['ይሁን',
#   'እንጅ',
#   'የባልደራስ',
#   'ክፍተኛ',
#   'አመራሮች',
#   'እና',
#   'በተለያዮ',
#   'ጊዚያት',
#   'በቂ',
#   'የሰው',
#   'እና',
#   'የንብረት',
#   'ማስረጃ'],
#  ['አለኝ',
#   'እያለ',
#   'ህዝብን',
#   'ሲያደናግር',
#   'የነበረው',
#   'አቃቢ',
#   'ህግ',
#   'ዛሬ',
#   'ምስክሮቼ',
#   'በድብቅ',
#   'ይመስክሩልኝ',
#   'ማለቱ',
#   'ትክክል'],
#  ['አይደለምነኔ',
#   'እኛ',
#   'የተክሰስንበት',
#   'ወንጀል',
#   'የዘር',
#   'ማጥፋት',
#   'አይነት',
#   'ወንጀልና',
#   'ከባድ',
#   'በመሆኑ',
#   'እንዲህ',
#   'አይነት'],
#  ['ወንጀል',
#   'በግልፅ',
#   'በህዝብ',
#   'ፊት',
#   'ነው',
#   'ዳኝነት',
#   'የሚስጠውነሀ',
#   'አቃቤ',
#   'ህግ',
#   'በድብቅ',
#   'ይመስክሩልኝ'],
#  ['ማለቱ',
#   'ሸፍጥን',
#   'ያሳያልጋ',
#   'ግልፅነት',
#   'ያስፈልጋል',
#   'ብሏል',
#   'እስክንድርሄ',
#   'ፍርድ',
#   'ቤቱ',
#   'ይህንን',
#   'ጥያቄ',
#   'ውድቅ',
#   'አድርጎ'],
#  ['ከመጋረጃ', 'በስተ', 'ጀርባ', 'ያለውን', 'የምስክርነት', 'ድራማ', 'ፈቅዷልነኔ'],
#  ['ከተሰዋ',
#   'በኋላ',
#   'አስከሬኑ',
#   'ጥግ',
#   'ሆኖ',
#   'እሸቴ',
#   'ደወለልኝነኔ',
#   'ላውጣላ',
#   'ስለው',
#   'ላልጄን',
#   'ትቼ',
#   'አላደርገውም',
#   'አለነፎ'],
#  ['ቆይቼ',
#   'ስደውል',
#   'ስልኩን',
#   'ጁንታው',
#   'አነሳውና',
#   'ላየት',
#   'ነህላ',
#   'አለኝጋ',
#   'እነርሱ',
#   'እንደሆኑ',
#   'ስለገባኝ',
#   'ላምን',
#   'አገባህላ',
#   'አልኩትነሀ'],
#  ['ቆይቼ',
#   'በሌላ',
#   'ስልከ',
#   'ደውየ',
#   'ሳናግረው',
#   'እሸቴን',
#   'ለምርመራ',
#   'እንደያዙት',
#   'ነገረኝነኔ',
#   'እኔም',
#   'እንደተሰዋ'],
#  ['ገባኝና',
#   'ወደ',
#   'ቦታው',
#   'ስመጣ',
#   'የአባትና',
#   'ልጁን',
#   'አስከሬን',
#   'አገኘሁጋ',
#   'በዚህ',
#   'ወቅት',
#   'እኔ',
#   'መከላከያ',
#   'ውስጥ',
#   'ነበርኩጋ'],
#  ['ጠላት',
#   'በየት',
#   'ቦታ',
#   'እንደሚሄድ',
#   'የተለያዩ',
#   'ሰዎች',
#   'መረጃ',
#   'ይሰጡኝ',
#   'ስለነበር',
#   'ደጋግሜ',
#   'ለመስማት',
#   'በእለቱ',
#   'ስልኬኘ'],
#  ['ድምፅ',
#   'እንዲቀርፅ',
#   'ከድርጌው',
#   'ነበርጆሀ',
#   'ለዚያ',
#   'ነው',
#   'ድምኡን',
#   'ማስቀረት',
#   'የቻልኩትጋ',
#   'እሸቴ',
#   'ሞገስ',
#   'የአሰፋ',
#   'ታየ',
#   'ዘመድ',
#   'ነበርጆሀ',
#   'አካባቢው'],
#  ['በጠላት',
#   'ተይዞ',
#   'ስለነበር',
#   'ሰው',
#   'አልነበረውምጆሀ',
#   'ይሄ',
#   'ቤት',
#   'የእሸቴ',
#   'ቤት',
#   'መስሏቸው',
#   'ነው',
#   'በከባድ',
#   'መሳሪያ'],
#  ['ያወደመትነሀ',
#   'አቶ',
#   'አሰፋ',
#   'ቤቱ',
#   'ከወደመ',
#   'በኋላ',
#   'በሌላ',
#   'ሰው',
#   'ቤት',
#   'ተጠልለው',
#   'ነው',
#   'ያሉት',
#   'ጡ'],
#  ['የባልደራስ',
#   'ፕሬዚደንት',
#   'አቶ',
#   'እስክንድር',
#   'ነጋ',
#   'ዞእሸቴን',
#   'ጀግና',
#   'የምንለው',
#   'የሞት',
#   'ፍርሀትን',
#   'ማሸነፍ',
#   'በመቻሉ'],
#  ['ነውጋ',
#   'ሞትን',
#   'መፍራት',
#   'ከቀይ',
#   'ሽብር',
#   'በኋላ',
#   'የመጣ',
#   'ነውጆሀ',
#   'ታሪክ',
#   'ሰሪ',
#   'የነበረ',
#   'ህዝብ',
#   'ታሪከ',
#   'ሲሰራበት'],
#  ['ዞሌሎችም',
#   'እንደኛ',
#   'አይነት',
#   'ቤተሰቦች',
#   'አሉጋ',
#   'እነርሱንምጠይቋቸውዞ',
#   'የአርበኛ',
#   'እሸቴ',
#   'ባለቤት'],
#  ['የባልደራስ',
#   'ለእውነተኛ',
#   'ዴሞክራሲ',
#   'ፓርቲ',
#   'ረባልደራስነ',
#   'ልኡክ',
#   'ቡድን',
#   'በሸዋ',
#   'ሮቢት',
#   'ከተማ',
#   'የትግራይ',
#   'ወራሪ'],
#  ['ቡድን',
#   'አባላትን',
#   'ገድለው',
#   'በክብር',
#   'የተሰውት',
#   'የአርበኛ',
#   'እሸቴ',
#   'ሞገስ',
#   'እና',
#   'የልጃቸው',
#   'ይታገሱ',
#   'እሸቴ',
#   'ቤተሰቦችን'],
#  ['ዛሬ',
#   'ማክሰኞ',
#   'ጥር',
#   'ነን',
#   'ቀን',
#   'ጀአነረነ',
#   'አምት',
#   'ጠይቀዋልነሀ',
#   'ዞወንድሜ',
#   'ሀገር',
#   'ሀገር',
#   'ሲል',
#   'ትኩረት',
#   'አልሰጠሁትም'],
#  ['ነበርሀ',
#   'አሁን',
#   'ግን',
#   'ኢትዮጵያዊነት',
#   'ምን',
#   'ማለት',
#   'እንደሆነ',
#   'በደንብ',
#   'ገብቶኛልጋ',
#   'ልጆቹን',
#   'እንደ',
#   'እሸቴ',
#   'አድርጌ',
#   'ነው'],
#  ['የማሳድጋቸውነኔ',
#   'እንዳውም',
#   'መጫት',
#   'ስለሆንኩ',
#   'እንጂ',
#   'መዝመትም',
#   'እፈልጋለሁዞ',
#   'ብለዋል',
#   'የአቶ',
#   'እሸቴ',
#   'እህት',
#   'ወፖሮ',
#   'በላይነሽነሀ'],
#  ['ለወንድማቸው',
#   'ተገቢው',
#   'የአርበኛ',
#   'ክብር',
#   'ስለተሰጠው',
#   'ደስተኛ',
#   'መሆናቸውንም',
#   'ገልፀዋልጋ',
#   'የቀብር',
#   'ስነ',
#   'ስርአቱ'],
#  ['እጅግ',
#   'ደማቅና',
#   'ክቡር',
#   'እንደነበርም',
#   'አስታውሰዋልነሀ',
#   'የአርበኛ',
#   'እሸቴ',
#   'ባለቤት',
#   'በበኩላቸው',
#   'ሀእኛን',
#   'ብዙ'],
#  ['ኢትዮጵያውያን',
#   'አፅናንተውናልያ',
#   'ደግፈውናልጋ',
#   'ሁለቱን',
#   'በአንድ',
#   'ገመዜ',
#   'ብናጣቸውም',
#   'ህዝቡ',
#   'ከእኛ',
#   'ጋር',
#   'ነውጋ'],
#  ['ሌሎችም', 'እንደ', 'እኛ', 'አይነት', 'ቤተሰቦች', 'አሉነሀ', 'እነርሱንም', 'ጠይቋቸውዞ', 'ብለዋልነሀ'],
#  ['ባልደራስ',
#   'ለእውነተኛ',
#   'ዲሞክራሲ',
#   'ፓርቲ',
#   'ከእስር',
#   'ከተፈቱ',
#   'አመራሮች',
#   'ጋር',
#   'የስራ',
#   'አስፈፃሚ',
#   'ኮሚቴ',
#   'ስብሰባ',
#   'አካሄደ'],
#  ['የባልደራስ',
#   'ለእውነተኛ',
#   'ዲሞክራሲ',
#   'ፓርቲ',
#   'የፓርቲው',
#   'ፕረዛዳንት',
#   'አቶ',
#   'እስክንድር',
#   'ነጋ',
#   'እና',
#   'የፓርቲው',
#   'የድርጅት'],
#  ['ጉዳይ',
#   'ሀላፊ',
#   'አቶ',
#   'ስንታየሁ',
#   'ቸኮል',
#   'በተገኙበት',
#   'በእስር',
#   'ላይ',
#   'ከነበሩ',
#   'አመራሮች',
#   'ጋር',
#   'ዛሬ',
#   'ጥር',
#   'አገፖጀአገጄ',
#   'አየምየ'],
#  ['የስራ', 'አስፈፃሚ', 'ኮሚቴ', 'ስብሰባ', 'አካሄዶ', 'ነበርበ'],
#  ['በእነ', 'አቶ', 'እስክንድር', 'ነጋ', 'መዝገብ', 'ስር', 'ተከሰው'],
#  ['የነበሩ', 'የፓርቲው', 'አመራሮችረአቶ', 'እስክንድር', 'ነጋቲ', 'አቶ'],
#  ['ስንታየሁ', 'ቸኮልተ', 'ወፖሮ', 'ቀለብ', 'ስዬምተ', 'ወፖሪት', 'አስካለ'],
#  ['ደምሌን', 'በተገኙበት', 'በሚቀጥለው', 'ሳምንት', 'በእስራቱ'],
#  ['ዙሪያ', 'እና', 'በሀገራችን', 'ወቅታዊ', 'ጉዳዮች', 'ላይ', 'ጋዜጣዊ'],
#  ['መግለጫ', 'እንደሚሰጡ', 'የፓርቲው', 'ስራ', 'አስፈፃሚ'],
#  ['ኮሚቴ', 'ወሳኔ', 'አስተላልፏልፂ'],
#  ['ጋዜጣዊ', 'መግለጫ', 'የሚሰጥበትን', 'ቀን', 'ለመገናኛ', 'ብዙሀን', 'በቅርቡ', 'እናሳውቃለንስ'],
#  ['የባልደራስ', 'ለእውነተኛ', 'ዲሞክራሲ', 'ፓርቲ', 'የስራ', 'አስፈፃሚ', 'ኮሚቴ', 'ጆሀ'],
#  ['አከቲቪዝም',
#   'ህዝቡን',
#   'ለመጠበቅ',
#   'ሲባል',
#   'መንግስለተወሰነ',
#   'ግዜ',
#   'ኢንተርኔት',
#   'በመዝጋት',
#   'ን',
#   'መረጃ'],
#  ['ቲቪን',
#   'ከሳተላይት',
#   'በማውረድና',
#   'አንዳንድ',
#   'የሀገር',
#   'ህልውና',
#   'ላይ',
#   'አደጋ',
#   'የጋረጡ',
#   'ግለሰቦችን',
#   'በክብር'],
#  ['በማረፊያ',
#   'ቤት',
#   'በማኖር',
#   'የውስጥ',
#   'ስራውን',
#   'እንዲሰራ',
#   'አናሳስባለንንኔ',
#   'በ',
#   'ኢትዮጵያ',
#   'ውስጥ',
#   'የኢንተርኔት',
#   'ገልግሎት',
#   'ለተወሰነ',
#   'ግዜ',
#   'ማቋረጥ',
#   'ን'],
#  ['ፀጋ',
#   'ከሀገር',
#   'ህልውና',
#   'አንፃር',
#   'አንደንድ',
#   'ግ',
#   'ለ',
#   'ሰ',
#   'ቦችን',
#   'የባልደራስ',
#   'ልኡክ',
#   'ቡድን',
#   'በፓርቲው',
#   'ፕሬዚደንት',
#   'አቶ'],
#  ['እስክንድር',
#   'ነጋ',
#   'የተመራ',
#   'ሲሆን',
#   'የድርጅቱ',
#   'ከፍተኛ',
#   'አመራሮች',
#   'ስንታየሁ',
#   'ቸኮልት',
#   'አስቴር',
#   'ስዩም',
#   'ርቀለብንታ'],
#  ['አስካለ', 'ደምሌት', 'ዘቢባ', 'ኢብራሂም', 'እና', 'ሶስና', 'ፈቃዱም', 'ተገኝተዋልጋ'],
#  ['ቡድኑ',
#   'የአማራ',
#   'ፋኖ',
#   'እየከፈለው',
#   'ላለው',
#   'መስዋእትነት',
#   'ከፍተኛ',
#   'ምስጋና',
#   'አቅርቧልጋ',
#   'አርበኛ',
#   'መሳፍንት',
#   'ተስፉም'],
#  ['ዘእስከ', 'ዛሬ', 'ብቻችንን', 'ታግለን', 'ውጤት'],
#  ['አስመዝግበናልጋ',
#   'ከአሁን',
#   'በኋላ',
#   'የእናንተን',
#   'እገዛ',
#   'ካገኘን',
#   'ይበልጥ',
#   'ስኬታማ',
#   'እንሆናለንዞ',
#   'ብለዋልጋ',
#   'ልኡክ'],
#  ['ቡድኑንም', 'አመስግነዋልጋ', 'አቶ', 'እስክንድር', 'ነጋ', 'በበኩላቸው', 'ዞአሁን', 'የፖለቲካ'],
#  ['ከጀንዳ',
#   'አይደለም',
#   'የያዝነውየ',
#   'ኢትዮጵያን',
#   'የማስቀጠል',
#   'ጉዳይ',
#   'ነውጋ',
#   'በታሪክም',
#   'ኢትዮጵያ',
#   'ችግር',
#   'ውስጥ'],
#  ['በገባች', 'ጊዜ', 'ሁሉ', 'በጀግንነታቸውን', 'ሀገር', 'የሚታደጉት', 'ፋኖዎች', 'ናቸውዞ', 'ብለዋልጋ'],
#  ['ፋኖ',
#   'አንድም',
#   'ሀገር',
#   'ብሄራዊ',
#   'ችግር',
#   'ሲገጥማትታ',
#   'ሌላም',
#   'እንደ',
#   'ህወሀት',
#   'አይነት',
#   'ጭራቅ',
#   'መንግስታት'],
#  ['ሲፈጠሩ',
#   'የሚፈጠር',
#   'መሆኑን',
#   'የገለኡት',
#   'አቶ',
#   'እስክንድር',
#   'የእነ',
#   'መሳፍንት',
#   'ነፍጥ',
#   'ማንሳትም',
#   'ከወያኔ',
#   'መብቀል',
#   'ጋር',
#   'የተያያዘ',
#   'መሆኑን',
#   'ኦብራርተዋልርሀ'],
#  ['አስከንድርን',
#   'ከቱባ',
#   'ወንጀለኖችና',
#   'ከዘር',
#   'ጨፍጫፊዎች',
#   'ጋር',
#   'ሲፈቱት',
#   'እንኳን',
#   'ደስ',
#   'አለህ'],
#  ['ይባባልልኛልህኔ',
#   'እዚህ',
#   'አገር',
#   'ስለ',
#   'ፍትህ',
#   'ከማስረዳት',
#   'ግመል',
#   'ይዞ',
#   'በመርፌ',
#   'ቀዳዳ',
#   'ማለፍ',
#   'ይቀላል',
#   'ህ'],
#  ['አንጭጭ', 'ሀ'],
#  ['ፍትህን', 'የሰዋች', 'ሀገርጅ'],
#  ['ህ', 'ግ', 'የሌ', 'ላት', 'ሀገ', 'ርጀ'],
#  ['ህ', 'ጋ', 'ፅህፓ', 'ኤ', 'ጆቆፓጋ', 'ጭ'],
#  ['ነው', 'የሚል', 'አይጠፋም', 'እኔ', 'ግን', 'ብኡእነታቸው'],
#  ['ለምን', 'ዝም', 'እንዳሉ', 'ግራ', 'ገብቶኝ', 'እወዛገባለሁ'],
#  ['ህወሀት', 'በቆቦ', 'ንኡሀንን', 'ስትጨፈጭፍ', 'ለምን', 'ዘምቷን', 'መረጡ', 'ፔኦ'],
#  ['እስክንድር', 'ግን', 'ዛሬም', 'በልባችን', 'ነውጁ'],
#  ['ሳናውቀው', 'ከአማራ', 'ደሪጋ', 'ህዝብ', 'ጋር', 'ቅራኔና', 'ቂም'],
#  ['ነበረው', 'ወይስ', 'ድርጅቱ', 'ሙሉ', 'ለሙሉ', 'በህወሀት', 'ቁጥጥር', 'ስር', 'ሆነ', 'ኚፆ'],
#  ['ሰበር', 'የመፈታት', 'ዜና'],
#  ['ለበአለ',
#   'ጥምቀቱ',
#   'ማስዋቢያ',
#   'ተብሎ',
#   'ከተሰራው',
#   'ከጊዮርጊሱ',
#   'ሀውልት',
#   'ጋር',
#   'በተያያዘ',
#   'ታስረው',
#   'ከነበሩት',
#   'ልጆች',
#   'መካከል',
#   'ቱን',
#   'ፖሊስ',
#   'አሁን'],
#  ['ለበአለ',
#   'ጥምቀቱ',
#   'ማስዋቢያ',
#   'ተብሎ',
#   'ከተሰራው',
#   'ከጊዮርጊሱ',
#   'ሀውልት',
#   'ጋር',
#   'በተያያዘ',
#   'ታስረው',
#   'ከነበሩት',
#   'ልጆች',
#   'መካከል',
#   'ቱን',
#   'ፖሊስ',
#   'አሁን',
#   'ይ',
#   'ፍርድ',
#   'ቤት',
#   'ወይም',
#   'የማይለቋቸው',
#   'ከሆነ',
#   'የአዲስ',
#   'አበባ',
#   'ወጣት',
#   'በሰላማዊሰልፍ',
#   'ጥያቄውን',
#   'ለማቅረብ',
#   'እንዲዘጋጅም',
#   'እየተመከረ',
#   'መሆኑም',
#   'ተሰምቷል'],
#  ['ቀደም',
#   'ሲል',
#   'ከተያዙት',
#   'ሶስት',
#   'ልጆች',
#   'በተጨማሪ',
#   'ትናንት',
#   'የተጨመረ',
#   'አንድ',
#   'ልጅ',
#   'ጋር',
#   'በድምሩ',
#   'አራት',
#   'ልጆች',
#   'አሁንም',
#   'በእስር',
#   'ላይ',
#   'ያሉ',
#   'ሲሆን',
#   'ልጆቹን'],
#  ['ሺ', 'ዶላር', 'ቀረን'],
#  ['በሀይማኖታቸው', 'ምክንያት', 'የተሰዉትን', 'የሰማእታቱን', 'ቤተሰቦች', 'ለማፅናናት'],
#  ['እንዳንረሳው'],
#  ['የአማኑኤል', 'አገዳደል', 'ይህን', 'ይመስል', 'ነበር'],
#  ['ፀጥታ',
#   'ሀይሎቹ',
#   'ግን',
#   'ወደ',
#   'ፍርድ',
#   'ቤት',
#   'ሳይሆን',
#   'ወደ',
#   'ካምፕ',
#   'ወስደው',
#   'ይቀጠቅጡት',
#   'ጀመር'],
#  ['ምን',
#   'አጠፋሁ',
#   'ምን',
#   'በደልኩ',
#   'ይላቸዋል',
#   'ዝም',
#   'ብለህ',
#   'የምናዝህን',
#   'ፈፅም',
#   'ይሉታል',
#   'የወታደር',
#   'የፖሊስና',
#   'የሚኒሻ',
#   'ዱላ',
#   'የበዛበት',
#   'አማኑኤልም',
#   'ፋታ',
#   'ባገኝ',
#   'ብሎ',
#   'እሺ',
#   'ይላቸዋል'],
#  ['እኔ',
#   'አባቶርቤ',
#   'ነኝ',
#   'እኔን',
#   'ያየህ',
#   'ተቀጣ',
#   'እያልክ',
#   'ደምቢዶሎ',
#   'ከተማን',
#   'ዙራት',
#   'ባሉት',
#   'መሰረት',
#   'አንድ',
#   'አሮጌ',
#   'ሰባራ',
#   'ሽጉጥ',
#   'በእጁ',
#   'አስይዘው',
#   'በስልካቸው',
#   'ቪድዮ',
#   'እየቀረፁ',
#   'በዝናብና',
#   'በባዶ',
#   'ሆዱ',
#   'ሲያንከራትቱት',
#   'ውለው',
#   'ወደ',
#   'መግደያው',
#   'አደባባይ',
#   'ይወስዱታል'],
#  ['ፖሊስ',
#   'ለቪኦኤ',
#   'ሊያመልጥ',
#   'ሲል',
#   'እግሩን',
#   'በጥይት',
#   'መተን',
#   'ነው',
#   'የያዝነው',
#   'የሚለው',
#   'እንዲህ',
#   'በሰላም',
#   'የሚራመድን',
#   'ልጅ',
#   'ነው',
#   'ከዚያስ',
#   'ምን',
#   'ሆነ',
#   'ቆይቼ',
#   'እመለሳለሁ'],
#  ['ሁል', 'ጊዜ', 'የዚህን', 'ልጅ', 'ቤተሰብ', 'የሚረዳበትን', 'መንገድ', 'አስብ', 'እብሰለሰል', 'ነበር'],
#  ['ጊዜው',
#   'ደረሰ',
#   'መሰለኝ',
#   'እንደ',
#   'አጋጣሚ',
#   'አሁን',
#   'ከሚሰበሰበው',
#   'የጎፈንድ',
#   'ሚ',
#   'ብር',
#   'ላይ',
#   'ለወላጆቹ',
#   'መላክ',
#   'እፈልጋለሁ',
#   'እና',
#   'እባካችሁ',
#   'ቤተሰቦቹን',
#   'የምታውቁ',
#   'አገናኙኝ'],
#  ['እየረዳችሁ', 'ሻሎም', 'ሰላም'],
#  ['ወዮ',
#   'እኔኮ',
#   'የት',
#   'ጠፋች',
#   'እላለሁ',
#   'ለካ',
#   'እሷ',
#   'ኢ',
#   'መደበኛ',
#   'ሆና',
#   'ነው',
#   'ወይ',
#   'ጉድ',
#   'ደግሞ',
#   'ኢ',
#   'መደበኛ',
#   'ስትሆን',
#   'ወፈረች',
#   'ይቅርታ',
#   'የእኔ',
#   'ነገር',
#   'መዘባረቅ',
#   'እኮ',
#   'ነው',
#   'አሁን',
#   'ጫልቱ',
#   'እህታችን',
#   'መደበኛ',
#   'ናት',
#   'ወይስ',
#   'ኢመደበኛ',
#   'ነው'],
#  ['ለማንኛውም',
#   'ይሄ',
#   'የምታዩት',
#   'አዲስ',
#   'ስንቅና',
#   'ትጥቅ',
#   'እየተሰፈረለት',
#   'የሚሰለጥነው',
#   'ለበቀል',
#   'የተዘጋጀ',
#   'ደማቸውን',
#   'እንበቀላለን',
#   'ብሎ',
#   'በሽመልስ',
#   'አብዲሳ',
#   'ክልል',
#   'በስልጠና',
#   'ላይ',
#   'ያለ',
#   'የቄሮ',
#   'መአት',
#   'የኦነግ',
#   'ሰራዊት',
#   'ነው'],
#  ['በነገራችን',
#   'ላይ',
#   'ሄርሚ',
#   'ኮንቾ',
#   'ምሳዋን',
#   'በልታ',
#   'ይሆን',
#   'ለእሷም',
#   'ለሚዲያዋ',
#   'ማቋቋሚያ',
#   'ዶላሩን',
#   'ጨመር',
#   'አድርጉ',
#   'እንጂ',
#   'ሆዳም',
#   'አማሮች',
#   'አትፍዘዙ',
#   'እንጂ',
#   'ሀይ',
#   'አቦ',
#   'ምንድነው',
#   'ሳ',
#   'ህ'],
#  ['እንዳንረሳው',
#   'ላስወሳችሁ',
#   'ብዬ',
#   'ነው',
#   'መንግስታዊው',
#   'ግድያ',
#   'ጨመረ',
#   'ቀነሰ',
#   'እስቲ',
#   'እንወያይ'],
#  ['በአረመኔዎቹና',
#   'በጨካኞቹ',
#   'የአብይ',
#   'ሽመልስ',
#   'የኦሮሚያ',
#   'ፖሊሶች',
#   'በአደባባይ',
#   'በግፍ',
#   'ከመረሸኑ',
#   'በፊት',
#   'ሲደበደብ',
#   'ውሎ',
#   'እንዲህ',
#   'ደሙ',
#   'እየፈሰሰ',
#   'በራብ',
#   'አንጀቱ',
#   'በአደባባዩ',
#   'ማዶ',
#   'ቆመው',
#   'ከአሁን',
#   'አሁን',
#   'ይለቁታል',
#   'ብለው',
#   'በመጠባበቅ',
#   'ላይ',
#   'የነበሩትን',
#   'ወላጅ',
#   'እናቱን',
#   'ነበር',
#   'ትኩር',
#   'ብሎ',
#   'ያይ',
#   'ይመለከት',
#   'የነበረው',
#   'አሉ'],
#  ['ወታደሩ',
#   'ወደ',
#   'አማኑኤል',
#   'ቀረብ',
#   'ብሎ',
#   'እንዴት',
#   'አድርጌ',
#   'ልግደልህ',
#   'ሲለው',
#   'የምር',
#   'መጨከናቸው',
#   'የገባው',
#   'ያኔ',
#   'ነበር'],
#  ['አማኑኤልም', 'ጀርባውን', 'ለገዳዩ', 'ለረሻኙ', 'ሰጥቶ', 'አሁን', 'ግደለኝ', 'ብሎ', 'ተኛለት', 'አሉ'],
#  ['ወታደሩም', 'በወላጅ', 'እናቱ', 'ፊት', 'የወጣቱን', 'አንጎል', 'በጥይት', 'በተነለት', 'የ'],
#  ['ኦሮሚያ',
#   'ክልል',
#   'መንግስትም',
#   'በጉዳዩ',
#   'ላይ',
#   'ሲጠየቅ',
#   'የወሰድነው',
#   'እርምጃ',
#   'ትክክልና',
#   'ተገቢ',
#   'ነው',
#   'አለ'],
#  ['አባዬ',
#   'ኦርቶዶክስ',
#   'ከሆንክ',
#   'ባለማእተብ',
#   'ከሆንክ',
#   'እንዲህ',
#   'እንደ',
#   'አማኑኤል',
#   'ያለ',
#   'እጣ',
#   'ነው',
#   'የሚደርስህ'],
#  ['ደግሞም',
#   'ማንም',
#   'አያስጥልህም',
#   'የውሸቱ',
#   'ህግ',
#   'ፊት',
#   'የመቅረብ',
#   'እድል',
#   'እንኳ',
#   'ማግኘት',
#   'አትችልም',
#   'ለምን',
#   'ይሄ',
#   'ይሆናል',
#   'ብለህ',
#   'ስትጠይቅ',
#   'ደግሞ',
#   'በአክራሪው',
#   'የፕሮና',
#   'ወሄ',
#   'የብልፅግና',
#   'መንግስት',
#   'ደጋፊ',
#   'ተከፋይ',
#   'ካድሬዎች',
#   'ጭምር',
#   'ትሰደባለህ'],
#  ['አየህ',
#   'አማኑኤልን',
#   'ኦሮሞነቱ',
#   'አላዳነውም',
#   'ገዳዮቹ',
#   'ዋነኛ',
#   'ጠባቸው',
#   'በሀይማኖት',
#   'ኦርቶዶክስ',
#   'በነገድ',
#   'አማራ',
#   'ከመሆንህ',
#   'ጋር',
#   'ብቻ',
#   'ነው'],
#  ['ተመለከትከው',
#   'የውሸት',
#   'ሹጉጡን',
#   'ምኑ',
#   'ላይ',
#   'እንዳንጠለጠሉት',
#   'አዎ',
#   'በአንገት',
#   'ማእተቡ',
#   'በመስቀሉ',
#   'ላይ',
#   'ነው',
#   'ያንጠለጠሉት'],
#  ['በአቢይ',
#   'አህመድ',
#   'ዘመን',
#   'ኦርቶዶክሳዊ',
#   'ሲገድሉ',
#   'መስቀሉን',
#   'በአፉ',
#   'አጉርሰው',
#   'እንደ',
#   'አማኑኤል',
#   'ደግሞ',
#   'መስቀል',
#   'ማእተብህ',
#   'ላይ',
#   'ሽጉጥ',
#   'አንጠልጥለው',
#   'ነው',
#   'የሚደፉህ'],
#  ['ፅዋው', 'እስኪሞላ', 'የሚከሰስ', 'የሚወቀስ', 'የለም'],
#  ['እድሜው',
#   'ገና',
#   'አመት',
#   'እንደሆነ',
#   'የተነገረለት',
#   'ኦርቶዶክሳዊ',
#   'ወጣት',
#   'አማኑኤል',
#   'ወንድሙ',
#   'ከበደ',
#   'ይባላል',
#   'ምእራብ',
#   'ወለጋ',
#   'በደምቢ',
#   'ዶሎ',
#   'ከተማ',
#   'ነዋሪ',
#   'የነበረም',
#   'ታዳጊ',
#   'ወጣትም',
#   'ነበር',
#   'የኦርቶዶክስ',
#   'ተዋህዶ',
#   'አማኝና',
#   'የሰንበት',
#   'ተማሪም',
#   'ነበር'],
#  ['ቄሮ',
#   'አለ',
#   'የትም',
#   'አልሄደ',
#   'ገሚሱ',
#   'የቦለጢቃ',
#   'ስራ',
#   'ላይ',
#   'ነው',
#   'ገሚሱ',
#   'ቢዝነስ',
#   'ጀምሯል'],
#  ['ማስጠንቀቂያ',
#   'በ',
#   'አትታጠፉ',
#   'ረጋ',
#   'ባላችሁ',
#   'አስቡ',
#   'ጊዜያዊ',
#   'እና',
#   'ዘላቂ',
#   'ጥቅም',
#   'ስለሚባሉ',
#   'ነገሮች',
#   'አስቡ',
#   'ከማን',
#   'ጋር',
#   'ምን',
#   'መስራት',
#   'እንዳለብን',
#   'እና',
#   'የትኛውን',
#   'ብቻችን',
#   'መከውን',
#   'እንዳለብን',
#   'ለይተን',
#   'እንወቅ'],
#  ['የበሻሻው',
#   'ጩሉሌ',
#   'ዛሬ',
#   'ባህር',
#   'ዳር',
#   'ገብቷል',
#   'የአማራ',
#   'ብልፅግና',
#   'አመራር',
#   'ሆይ',
#   'ከአብይና',
#   'ከአማራ',
#   'ህዝብ',
#   'አንዱን',
#   'ምረጡ'],
#  ['አብይ', 'አንድም', 'የአሜሪካን', 'ትእዛዝ', 'ለማስፈፀም'],
#  ['በተለይም',
#   'በወልቃይትና',
#   'ራያ',
#   'ጉዳዮች',
#   'ላይ',
#   'ከብአዴን',
#   'ጋር',
#   'ለመነጋገር',
#   'ወይም',
#   'ስለአማራው',
#   'ቀንደኛ',
#   'ጠላት',
#   'አቦይ',
#   'ስብሀት',
#   'መፈታት',
#   'ህዝቡን',
#   'ምን',
#   'ብለው',
#   'ማታለል',
#   'እንዳለባቸው',
#   'ለማማከር'],
#  ['ወይም',
#   'አሜሪካ',
#   'ለአብይ',
#   'የሰጠችው',
#   'ቀጭን',
#   'ትዛዝ',
#   'እስከምን',
#   'ድረስ',
#   'እንደሆነ',
#   'ለአማራ',
#   'ግኡዝ',
#   'ብልፅግና',
#   'አባላት',
#   'ለማስረዳት',
#   'ሳይሆን',
#   'አልቀረም'],
#  ['አማራ',
#   'ንቃ',
#   'በእንደዚህ',
#   'አይነት',
#   'ሁኔታዎች',
#   'በእውነተኛ',
#   'መሪዎቻችን',
#   'ላይ',
#   'ጉዳት',
#   'እንዳይደርስ'],
#  ['የትግራይ',
#   'ወራሪ',
#   'ለዘመናት',
#   'ያከማቻቸውን',
#   'እና',
#   'ከሰሜን',
#   'እዝ',
#   'የዘረፈውን',
#   'ሮኬት',
#   'መድፍ',
#   'ታንክ',
#   'ዙ',
#   'ሞርተር',
#   'እና',
#   'ሌሎች',
#   'ስንጥቅ',
#   'የወገን',
#   'ጦር',
#   'ያልነበረውን',
#   'ዘመናዊ',
#   'መሳሪያ',
#   'እና',
#   'ከ',
#   'በላይ',
#   'አክቲቭ',
#   'ሰራዊት',
#   'እና',
#   'ግትልትል',
#   'ጀሌ',
#   'ይዞ',
#   'ወደ',
#   'አማራ',
#   'ክልል',
#   'መስፋፋት',
#   'በሞከረበት',
#   'በዚያ',
#   'ጨለማ',
#   'ቀን',
#   'ጥቅምት'],
#  ['አሸባሪውን',
#   'ለማጥፋት',
#   'በሚደረገው',
#   'ትግል',
#   'ትልቁ',
#   'ደንቃራ',
#   'ኦሮሞ',
#   'መራሹ',
#   'የፌደራል',
#   'መንግስቱ',
#   'ነው',
#   'ለዚህ',
#   'ደግም',
#   'ምክንያቶችን',
#   'ማቅረብ',
#   'እንችላለን',
#   'ግን',
#   'እሱ',
#   'የዚህ',
#   'ፁህፍ',
#   'አላማ',
#   'አይደለም',
#   'አስፈላጊ',
#   'ነው',
#   'ብላችሁ',
#   'ካሰባችሁ',
#   'በቀጣይ',
#   'በሰፊው',
#   'ሀተታ',
#   'አቀርብላችኋለው'],
#  ['አሁን',
#   'በፌደራል',
#   'መንግስቱ',
#   'አያያዝ',
#   'ህውሀትን',
#   'ማስወገድ',
#   'በጭራሽ',
#   'የማይታሰብ',
#   'ነው',
#   'እንዲያውም',
#   'ትጥቅ',
#   'እያስረከበ',
#   'እና',
#   'ሙሉ',
#   'ትግራይ',
#   'የህውሀት',
#   'ደጋፊ',
#   'እንዲሆን',
#   'አድርጎታል'],
#  ['በዚህ',
#   'ላይ',
#   'ጦርነቱ',
#   'አልቋል',
#   'ስለድህረ',
#   'ጦርነት',
#   'እናውራ',
#   'የተበተነ',
#   'ዱቄት',
#   'ነው',
#   'እንዲህ',
#   'አይነት',
#   'ሽንፈት',
#   'በዘራችሁ',
#   'አይደረስባችሁ',
#   'እያሉ',
#   'ህዝቡን',
#   'ከጠላት',
#   'እኩል',
#   'ያዘናጋሉ'],
#  ['ከዳን', 'መዳኛችን', 'ፈጣሪና', 'ክንዳችን', 'ብቻ', 'ነው'],
#  ['ሸር'],
#  ['ሼር', 'ይደረግ'],
#  ['እነዚህ',
#   'በፎቶው',
#   'የምትመለከቷቸው',
#   'አማራዎች',
#   'በማንነታቸው',
#   'ምክንያት',
#   'ብቻ',
#   'ከወለጋ',
#   'የተፈናቀሉ',
#   'ናቸው'],
#  ['ህፃናቶቹ',
#   'ደግሞ',
#   'የሚጫወቱት',
#   'የሚያወሩት',
#   'የሚዝናኑቱ',
#   'እና',
#   'የሚግባቡት',
#   'በኦሮሞኛ',
#   'ቋንቋ',
#   'መሆኑን',
#   'ስታይ',
#   'ደግሞ',
#   'የበለጠ',
#   'ሁኔታው',
#   'ያስገርምሀል',
#   'ያሳዝንሀል'],
#  ['ከወለጋ',
#   'ከተፈናቀሉ',
#   'በኋላ',
#   'ከዚህ',
#   'መውጣት',
#   'አትችሉም',
#   'እየተባሉ',
#   'በአካባቢ',
#   'የኦሮሞ',
#   'ብልፅግና',
#   'አመራሮች',
#   'ሲንገላቱ',
#   'ቆይተው',
#   'በመጨረሻም',
#   'አዲስ',
#   'አበባ',
#   'ለመድረስ',
#   'በቅተው',
#   'ነበር'],
#  ['በአዲስ',
#   'አበባ',
#   'ኮልፌ',
#   'አካባቢ',
#   'በነበረው',
#   'የመጠላያ',
#   'ካንፕ',
#   'ለተወሰነ',
#   'ጊዜ',
#   'ቢቆዩም',
#   'የእነ',
#   'አዳነች',
#   'አበቤ',
#   'መንግስት',
#   'ከተማችን',
#   'እንድትኖሩ',
#   'አንፈቅድላችሁም',
#   'በሚሉ',
#   'ከመጠለያ',
#   'ካንፑ',
#   'በፖሊስ',
#   'እየተደበደቡ',
#   'ተባረዋል'],
#  ['ተረኛው',
#   'መንግስት',
#   'ኦሮሞ',
#   'ከሱማሌ',
#   'ተፈናቅሎ',
#   'ሲመጣ',
#   'አንድ',
#   'ቀበሌ',
#   'በሚያክል',
#   'ቦታ',
#   'ቤት',
#   'ገንብቶ',
#   'ከ',
#   'በላይ',
#   'ኦሮሞዎችን',
#   'አስፍሮ',
#   'ነበር',
#   'አማራ',
#   'ሲሆን',
#   'ግን',
#   'ከተማው',
#   'ውስጥ',
#   'እንኳን',
#   'እንዲንቀሳቀስ',
#   'አልተፈቀደም'],
#  ['የተወሰኑት',
#   'ተበትነው',
#   'አዲስ',
#   'አበባ',
#   'በየጎዳናው',
#   'ወድቀዋል',
#   'የበረቱት',
#   'ደግሞ',
#   'እንደምታያቸው',
#   'ደብረ',
#   'ብርሀን',
#   'ደርሰው',
#   'በ',
#   'የመጠለያ',
#   'ካንፕ',
#   'ውስጥ',
#   'ናቸው'],
#  ['አማራ', 'የሆነ', 'ሁሉ', 'ለነዚህ', 'ወገኖ'],
#  ['ቻችን', 'የሚችለውን', 'ሊያደርግ', 'ይገባል'],
#  ['መንግስት',
#   'በአስቸኳይ',
#   'ለአፋር',
#   'ህዝብ',
#   'ሊደርስ',
#   'ይገባል',
#   'አቅም',
#   'አለን',
#   'ዝግጁ',
#   'ነን',
#   'ያለው',
#   'መንግስት',
#   'ለአፋር',
#   'ህዝብ',
#   'በአስቸኳይ',
#   'መድረስ',
#   'ካልቻለ',
#   'ራሱ',
#   'ሀገር',
#   'የማፍረስ',
#   'እቅድ',
#   'እንዳለው',
#   'እንድንጠረጥር',
#   'ያደርገናል'],
#  ['ምድራዊ',
#   'ድሮን',
#   'እያሉ',
#   'በማሞካሸት',
#   'ህዝቡን',
#   'እስከ',
#   'አፍንጫው',
#   'በታጠቀው',
#   'አሸባሪ',
#   'ቡድን',
#   'ማስጨፍጨፍ',
#   'ታሪክ',
#   'ይቅር',
#   'የማይለው',
#   'እና',
#   'አፋሮችንም',
#   'በኢትዮጵያዊነታቸው',
#   'ተስፋ',
#   'እንዲቆርጡ',
#   'የሚያደርግ',
#   'አደገኛ',
#   'ተግባር'],
#  ['የብልፅግና', 'ኢትዮጵያ', 'ስትገመገም'],
#  ['በአማራ',
#   'ደም',
#   'የመከበር',
#   'እንጂ',
#   'እንደማንኛውም',
#   'ብሄር',
#   'አማራን',
#   'የማክበር',
#   'ፍላጎት',
#   'የላትም'],
#  ['በአማራ',
#   'ህዝብ',
#   'ስብራትና',
#   'ጉዳት',
#   'ላይ',
#   'ካልሆነ',
#   'በቀር',
#   'በእሱ',
#   'እኩልነትና',
#   'ተጠቃሚነት',
#   'ላይ',
#   'ቀጣይነቷን',
#   'ማረጋገጥ',
#   'አትሻም'],
#  ['አማራ',
#   'የሚባለው',
#   'ህዝብ',
#   'ለእሷ',
#   'ህልውና',
#   'ደሙን',
#   'ከማፍሰስ',
#   'ባለፈ',
#   'እሷን',
#   'በማፍረስ',
#   'ሂደት',
#   'ውስጥ',
#   'ፋይዳ',
#   'አለው',
#   'ብላ',
#   'አታምንም'],
#  ['በተደጋጋሚ',
#   'በፈፀመችበት',
#   'ክህደትና',
#   'ጥቃት',
#   'ተገፋፍቶ',
#   'በአገር',
#   'አፍራሽነት',
#   'የሚሳተፍና',
#   'በውጫዊ',
#   'ሀይሎች',
#   'የሚደገፍ',
#   'አማፂ',
#   'አማራ',
#   'ክልል',
#   'ውስጥ',
#   'የተፈጠረ',
#   'እንደሁ',
#   'ምን',
#   'ሊፈጠር',
#   'እንደሚችል',
#   'አትረዳም'],
#  ['እንደ',
#   'አገር',
#   'አማራን',
#   'አሸናፊ',
#   'ከሚያደርግ',
#   'ድል',
#   'ይልቅ',
#   'አማራን',
#   'ጠፊ',
#   'እርሷን',
#   'ተሸናፊ',
#   'የሚያደርግ',
#   'ትግል',
#   'ይመስጣታል'],
#  ['እሷን',
#   'ለማፍረስ',
#   'በተነሳ',
#   'ጠላት',
#   'ከግማሽ',
#   'ትሪሊየን',
#   'ብር',
#   'በላይ',
#   'የሆነ',
#   'ሀብት',
#   'ከወደመበት',
#   'ክልል',
#   'ይልቅ',
#   'የሰሜን',
#   'እዝን',
#   'ወግቶ',
#   'በለኮሰው',
#   'ጦርነት',
#   'የመቶ',
#   'ቢሊዮን',
#   'ብር',
#   'የበጀት',
#   'ካሳ',
#   'የሰጠችው',
#   'አካል',
#   'አንጀቷን',
#   'ይበላዋል'],
#  ...]

# %%
word2vec_model = KeyedVectors.load_word2vec_format('Embeddings/5w_10ng_am_w2v_cbow_300D.txt', binary=False, encoding='utf-8')

# %%
# Function to generate document vectors
def generate_doc_vector(sentence):
    vectors = [word2vec_model[word] for word in sentence if word in word2vec_model]
    if not vectors:
        return np.zeros(word2vec_model.vector_size)
    return np.mean(vectors, axis=0)

# %%
X = [generate_doc_vector(sentence) for sentence in tokenized_sentences]

# %%
# Splitting into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2, random_state=42)

# %%
# Initialize and train logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# %%
# Evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Logistic Regression Accuracy:", accuracy)
# Out:
# Logistic Regression Accuracy: 0.7041884816753927

# %%
classification_LR = classification_report(y_test, y_pred)
print("\nLRClassification Report:")
print(classification_LR)
# Out:
# LRClassification Report:
#               precision    recall  f1-score   support
#
#         Free       0.71      0.74      0.73       603
#    Offensive       0.70      0.66      0.68       543
#
#     accuracy                           0.70      1146
#    macro avg       0.70      0.70      0.70      1146
# weighted avg       0.70      0.70      0.70      1146

# %%
conf_matrix_LR = confusion_matrix(y_test, y_pred)
print("\nLRConfusion Matrix:")
print(conf_matrix_LR)
# Out:
# LRConfusion Matrix:
# [[447 156]
#  [183 360]]

# %%
# Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf_predictions = rf_model.predict(X_test)

# %%
# Evaluate accuracy
accuracy = accuracy_score(y_test, rf_predictions)
print("Random Forest Accuracy:", accuracy)
# Out:
# Random Forest Accuracy: 0.7268760907504364

# %%
classification_RF = classification_report(y_test, rf_predictions)
print("\nRFClassification Report:")
print(classification_RF)
# Out:
# RFClassification Report:
#               precision    recall  f1-score   support
#
#         Free       0.72      0.78      0.75       603
#    Offensive       0.73      0.67      0.70       543
#
#     accuracy                           0.73      1146
#    macro avg       0.73      0.72      0.72      1146
# weighted avg       0.73      0.73      0.73      1146

# %%
conf_matrix_RF = confusion_matrix(y_test, rf_predictions)
print("\nRFConfusion Matrix:")
print(conf_matrix_RF)
# Out:
# RFConfusion Matrix:
# [[471 132]
#  [181 362]]

# %%
# Support Vector Machine (SVM) Classifier
svm_model = SVC(kernel='linear')
svm_model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
svm_predictions = svm_model.predict(X_test)

# %%
# Evaluate accuracy
accuracy = accuracy_score(y_test, svm_predictions)
print("SVM Accuracy:", accuracy)
# Out:
# SVM Accuracy: 0.7207678883071553

# %%
classification_SVM = classification_report(y_test, svm_predictions)
print("\nSVMClassification Report:")
print(classification_SVM)
# Out:
# SVMClassification Report:
#               precision    recall  f1-score   support
#
#         Free       0.74      0.73      0.73       603
#    Offensive       0.70      0.71      0.71       543
#
#     accuracy                           0.72      1146
#    macro avg       0.72      0.72      0.72      1146
# weighted avg       0.72      0.72      0.72      1146

# %%
conf_matrix_SVM = confusion_matrix(y_test, svm_predictions)
print("\nSVMConfusion Matrix:")
print(conf_matrix_SVM)
# Out:
# SVMConfusion Matrix:
# [[438 165]
#  [155 388]]
